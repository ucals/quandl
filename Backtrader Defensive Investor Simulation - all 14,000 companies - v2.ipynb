# %% [markdown]
# # Backtrader Defensive Investor Simulation - all 14,000 companies - v2
# **Purpose.** The purpose of this notebook is to simulate the application of Ben Graham's *Defensive Investor's criteria (as described in Chapter 14 of Intelligent Investor)* in a portfolio strategy over the past 10 years.
#
# **Pre-work.** This notebook builds on output saved on disk, to speed up the process - the following steps are very time-consuming:
# 1. [Download Quandl data to apply Defensive Investor's criteria](http://localhost:8889/notebooks/Download%20Quandl%20data%20to%20apply%20Defensive%20Investor's%20criteria.ipynb) saves fundamentals data from all 14,121 companies in Quandl Sharadar/SF1 database needed to apply defensive investor's test in a CSV file, to be used in step 2.
# 2. [Evolution of companies meeting Defensive Investor criteria over time](http://localhost:8888/notebooks/Evolution%20of%20companies%20meeting%20Defensive%20Investor%20criteria%20over%20time.ipynb) saves all companies passing the first 5 criteria in a pickle file (the last 2 criteria will be tested in this notebook), to be used in step 3 and in this notebook.
# 3. [Download Daily Prices, PE & PB data from all companies passing Defensive Investor Criteria](http://localhost:8888/notebooks/Download%20Daily%20Prices%2C%20PE%20%26%20PB%20data%20from%20all%20companies%20passing%20Defensive%20Investor%20Criteria.ipynb) saves daily prices, PE and PB ratios from the list in previous step in a CSV file, to be used in this notebook.

# %% [markdown]
# ## Step 1: Load all pre-processed data needed to run the simulation

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os
import quandl
import pandas_datareader as pdr
from datetime import datetime, timedelta
import calendar
import backtrader as bt
import backtrader.feeds as btfeeds
import backtrader.analyzers as btanalyzers
import matplotlib.pyplot as plt
import pickle
from graham import *

quandl.ApiConfig.api_key = os.getenv('QUANDL_APY_KEY')

# %%
fname_companies = os.path.join(os.getcwd(), 'data_defensive', 'defensive2_companies_20081231_20181231.pkl')
fname_pricedata = os.path.join(os.getcwd(), 'data_defensive', 'defensive2_pricedata_20081231_20181231.csv')

# %%
def load_obj(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)
    
dc_companies = load_obj(fname_companies)
df_pricedata = pd.read_csv(fname_pricedata, index_col=0, parse_dates=['date'])

# %%
def get_trading_data(ticker):
    df = df_pricedata[df_pricedata['ticker'] == ticker][['date', 'open', 'high', 'low', 'close', 'volume', 'pe', 'pb']]
    df.set_index('date', inplace=True)
    return df

# %% [markdown]
# There might be companies which pass the test criteria, but without trading data. The code below fix it, removing these companies:

# %%
all_companies_passing_in_period = set()
for key, value in dc_companies.items():
    for el in value:
        all_companies_passing_in_period.add(el)
        
all_companies_passing_in_period = list(all_companies_passing_in_period)

for ticker in all_companies_passing_in_period:
    data = get_trading_data(ticker)
    if (data.shape[0] == 0):
        print(f'Problem with {ticker}: pass the criteria, but does not have all trading data. Removing it.')
        all_companies_passing_in_period.remove(ticker)
        for key, value in dc_companies.items():
            if ticker in value:
                value.remove(ticker)
                
for ticker in all_companies_passing_in_period:
    data = get_trading_data(ticker)
    if (data.index[-1] != get_trading_data('NKE').index[-1]):
        print(f'Problem with {ticker}: pass the criteria, but does not have all trading data. Removing it.')
        all_companies_passing_in_period.remove(ticker)
        for key, value in dc_companies.items():
            if ticker in value:
                value.remove(ticker)
# Out:
# Problem with ABI1: pass the criteria, but does not have all trading data. Removing it.
# Problem with BEAM: pass the criteria, but does not have all trading data. Removing it.
# Problem with NJDCY: pass the criteria, but does not have all trading data. Removing it.
# Problem with SIAL: pass the criteria, but does not have all trading data. Removing it.
# Problem with RSH: pass the criteria, but does not have all trading data. Removing it.
# Problem with BCR: pass the criteria, but does not have all trading data. Removing it.
# Problem with GR: pass the criteria, but does not have all trading data. Removing it.
# Problem with PCP: pass the criteria, but does not have all trading data. Removing it.
# Problem with PLL1: pass the criteria, but does not have all trading data. Removing it.
# Problem with MON: pass the criteria, but does not have all trading data. Removing it.

# %% [markdown]
# Now we can continue. Let's check the data we pulled.

# %%
df = pd.DataFrame(columns=['companies_passing'], index=dc_companies.keys())
for key, value in dc_companies.items():
    df.at[key, 'companies_passing'] = len(value)

df['perc_companies_passing'] = df['companies_passing'] / 14121    
df['companies_passing'].plot(figsize=(14, 7), 
                                  title='Evolution of companies passing defensive investors criteria over time')

# %%
get_trading_data('NKE')[['close']].plot(figsize=(14, 7), title='Nike common stock closing prices')

# %% [markdown]
# ## Step 2: Define the trading strategy

# %% [markdown]
# It is very important to retrieve companies passing the criteria for a given date. Let's do it:

# %%
def get_passing_companies(date):
    month_ago = date - timedelta(365 / 12)
    year = month_ago.year
    month = month_ago.month
    day = calendar.monthrange(year, month)[1]
    closest_last_month = datetime(year, month, day)
    return dc_companies[closest_last_month]

# %%
#get_passing_companies(datetime(2009, 1, 15))
#get_trading_data('ABI1')

# %% [markdown]
# Now we are ready to implement the strategy:

# %%
class TestStrategy(bt.Strategy):
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        #print(self.getdatanames())
        self.cash = 0
        self.order = None
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY {order.data.params.name} EXECUTED, Price: {order.executed.price:.2f}, Amount: {order.executed.size:.2f}, PE: {order.data.pe[0]}')
            elif order.issell():
                self.log(f'SELL {order.data.params.name} EXECUTED, Price: {order.executed.price:.2f}, Amount: {order.executed.size:.2f}, PE: {order.data.pe[0]}')

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def next(self):
        for ticker in get_passing_companies(self.datas[0].datetime.date(0)):
            line = self.dnames[ticker]
            if self.getposition(line).size == 0:
                if line.pe[0] < 15 and line.pe[0] > 0:
                    if (line.pb[0] < 1.5) or (line.pe[0] * line.pb[0] < 22.5):
                        #self.log(f"{ticker} BUY opportunity at {line.close[0]}, PE {line.pe[0]}")
                        self.order = self.buy(data=line, size=int(5000.0 / line.close[0]))
            #else:
                #if line.pe[0] > 50:
                    #self.log(f"{ticker} SELL opportunity at {line.close[0]}, PE {line.pe[0]}")
                    #self.order = self.sell(data=line, size=self.getposition(line).size)

# %% [markdown]
# ## Step 3: Run the strategy

# %%
class PandasDataPEPB(btfeeds.PandasData):
    lines = ('pe', 'pb', )
    params = (('pe', -1), ('pb', -1), ) # ('name', 'teste'), )

# %%
# Create a cerebro entity
cerebro = bt.Cerebro()

# Add a strategy
cerebro.addstrategy(TestStrategy)

# Add all data
for ticker in all_companies_passing_in_period: #[:10]:
    data = PandasDataPEPB(dataname=get_trading_data(ticker), name=ticker)
    cerebro.adddata(data)

# %%
a = datetime.now()

cerebro.broker.setcash(200000.0)

# Adding analyzers
cerebro.addanalyzer(btanalyzers.AnnualReturn, _name='ar')
cerebro.addanalyzer(btanalyzers.TimeReturn, _name='tr')
#cerebro.addobserver(bt.observers.Value)

# Print out the starting conditions
initial_value = cerebro.broker.getvalue()
print(f'Starting Portfolio Value: {initial_value:,}')

# Run over everything
thestrats = cerebro.run()
thestrat = thestrats[0]

# Print out the final result
final_value = cerebro.broker.getvalue()
print(f'Final Portfolio Value: {final_value:,}')

print(f'\nTime to execute: {(datetime.now() - a)}')
# Out:
# Starting Portfolio Value: 200,000.0
# 2009-01-02, BUY AIT EXECUTED, Price: 19.00, Amount: 264.00, PE: 9.1
# 2009-01-02, BUY ALB EXECUTED, Price: 22.24, Amount: 224.00, PE: 8.8
# 2009-01-02, BUY ASH EXECUTED, Price: 5.28, Amount: 951.00, PE: 2.1
# 2009-01-02, BUY BEN EXECUTED, Price: 21.29, Amount: 235.00, PE: 9.8
# 2009-01-02, BUY BMS EXECUTED, Price: 24.06, Amount: 211.00, PE: 14.0
# 2009-01-02, BUY CSL EXECUTED, Price: 20.67, Amount: 241.00, PE: 15.3
# 2009-01-02, BUY CTAS EXECUTED, Price: 23.23, Amount: 215.00, PE: 11.0
# 2009-01-02, BUY ESV EXECUTED, Price: 28.25, Amount: 176.00, PE: 3.9
# 2009-01-02, BUY HP EXECUTED, Price: 23.10, Amount: 219.00, PE: 5.7
# 2009-01-02, BUY ITW EXECUTED, Price: 35.15, Amount: 142.00, PE: 10.7
# 2009-01-02, BUY LB EXECUTED, Price: 10.14, Amount: 498.00, PE: 5.8
# 2009-01-02, BUY LECO EXECUTED, Price: 25.59, Amount: 196.00, PE: 9.5
# 2009-01-02, BUY NUE EXECUTED, Price: 46.95, Amount: 108.00, PE: 7.3
# 2009-01-02, BUY PFE EXECUTED, Price: 17.88, Amount: 282.00, PE: 11.7
# 2009-01-02, BUY RS EXECUTED, Price: 20.04, Amount: 250.00, PE: 3.2
# 2009-01-02, BUY SCHN EXECUTED, Price: 37.24, Amount: 132.00, PE: 4.5
# 2009-01-02, BUY SEB EXECUTED, Price: 1195.00, Amount: 4.00, PE: 9.4
# 2009-01-02, BUY THO EXECUTED, Price: 13.35, Amount: 379.00, PE: 12.6
# 2009-01-02, BUY TIF EXECUTED, Price: 23.93, Amount: 211.00, PE: 10.2
# 2009-01-15, BUY SCCO EXECUTED, Price: 14.29, Amount: 345.00, PE: 7.1
# 2009-03-04, BUY ATR EXECUTED, Price: 26.60, Amount: 191.00, PE: 11.8
# 2009-03-04, BUY HOG EXECUTED, Price: 9.68, Amount: 539.00, PE: 3.2
# 2009-03-04, BUY HUBB EXECUTED, Price: 24.39, Amount: 207.00, PE: 6.4
# 2009-03-04, BUY PNR EXECUTED, Price: 19.62, Amount: 261.00, PE: 8.6
# 2009-03-04, BUY SKYW EXECUTED, Price: 8.64, Amount: 588.00, PE: 4.6
# 2009-03-04, BUY SNA EXECUTED, Price: 22.21, Amount: 227.00, PE: 5.4
# 2009-03-06, BUY MDT EXECUTED, Price: 25.92, Amount: 194.00, PE: 9.8
# 2009-03-24, BUY HRS EXECUTED, Price: 28.02, Amount: 177.00, PE: 12.2
# 2009-08-03, BUY CAG EXECUTED, Price: 19.87, Amount: 254.00, PE: 9.0
# 2010-03-04, BUY BMY EXECUTED, Price: 24.38, Amount: 205.00, PE: 4.0
# 2011-06-01, BUY UVV EXECUTED, Price: 42.13, Amount: 118.00, PE: 6.7
# 2011-08-05, BUY RBC EXECUTED, Price: 54.39, Amount: 88.00, PE: 14.2
# 2011-09-01, BUY ADM EXECUTED, Price: 28.50, Amount: 175.00, PE: 9.4
# 2012-03-05, BUY BHI EXECUTED, Price: 48.86, Amount: 101.00, PE: 12.1
# 2012-03-05, BUY CW EXECUTED, Price: 36.59, Amount: 135.00, PE: 13.3
# 2012-06-12, BUY WMK EXECUTED, Price: 42.77, Amount: 117.00, PE: 15.1
# 2012-07-13, BUY CAJ EXECUTED, Price: 37.22, Amount: 134.00, PE: 15.0
# 2012-09-20, BUY INTC EXECUTED, Price: 23.09, Amount: 215.00, PE: 9.4
# 2013-03-05, Order Canceled/Margin/Rejected
# 2013-03-05, BUY ABT EXECUTED, Price: 34.38, Amount: 145.00, PE: 9.1
# 2013-03-06, Order Canceled/Margin/Rejected
# 2013-03-07, Order Canceled/Margin/Rejected
# 2013-03-08, Order Canceled/Margin/Rejected
# 2013-03-11, Order Canceled/Margin/Rejected
# 2013-03-12, Order Canceled/Margin/Rejected
# 2013-03-13, Order Canceled/Margin/Rejected
# 2013-03-14, Order Canceled/Margin/Rejected
# 2013-03-15, Order Canceled/Margin/Rejected
# 2013-03-18, Order Canceled/Margin/Rejected
# 2013-03-19, Order Canceled/Margin/Rejected
# 2013-03-20, Order Canceled/Margin/Rejected
# 2013-03-21, Order Canceled/Margin/Rejected
# 2013-03-22, Order Canceled/Margin/Rejected
# 2013-03-25, Order Canceled/Margin/Rejected
# 2013-03-26, Order Canceled/Margin/Rejected
# 2013-03-27, Order Canceled/Margin/Rejected
# 2013-03-28, Order Canceled/Margin/Rejected
# 2013-04-01, Order Canceled/Margin/Rejected
# 2013-04-02, Order Canceled/Margin/Rejected
# 2013-04-03, Order Canceled/Margin/Rejected
# 2013-04-04, Order Canceled/Margin/Rejected
# 2013-04-04, Order Canceled/Margin/Rejected
# 2013-04-05, Order Canceled/Margin/Rejected
# 2013-04-05, Order Canceled/Margin/Rejected
# 2013-04-08, Order Canceled/Margin/Rejected
# 2013-04-08, Order Canceled/Margin/Rejected
# 2013-04-09, Order Canceled/Margin/Rejected
# 2013-04-09, Order Canceled/Margin/Rejected
# 2013-04-10, Order Canceled/Margin/Rejected
# 2013-04-11, Order Canceled/Margin/Rejected
# 2013-04-11, Order Canceled/Margin/Rejected
# 2013-04-12, Order Canceled/Margin/Rejected
# 2013-04-12, Order Canceled/Margin/Rejected
# 2013-04-15, Order Canceled/Margin/Rejected
# 2013-04-15, Order Canceled/Margin/Rejected
# 2013-04-16, Order Canceled/Margin/Rejected
# 2013-04-16, Order Canceled/Margin/Rejected
# 2013-04-17, Order Canceled/Margin/Rejected
# 2013-04-17, Order Canceled/Margin/Rejected
# 2013-04-18, Order Canceled/Margin/Rejected
# 2013-04-18, Order Canceled/Margin/Rejected
# 2013-04-19, Order Canceled/Margin/Rejected
# 2013-04-19, Order Canceled/Margin/Rejected
# 2013-04-22, Order Canceled/Margin/Rejected
# 2013-04-22, Order Canceled/Margin/Rejected
# 2013-04-23, Order Canceled/Margin/Rejected
# 2013-04-23, Order Canceled/Margin/Rejected
# 2013-04-24, Order Canceled/Margin/Rejected
# 2013-04-24, Order Canceled/Margin/Rejected
# 2013-04-25, Order Canceled/Margin/Rejected
# 2013-04-25, Order Canceled/Margin/Rejected
# 2013-04-26, Order Canceled/Margin/Rejected
# 2013-04-26, Order Canceled/Margin/Rejected
# 2013-04-29, Order Canceled/Margin/Rejected
# 2013-04-29, Order Canceled/Margin/Rejected
# 2013-04-30, Order Canceled/Margin/Rejected
# 2013-04-30, Order Canceled/Margin/Rejected
# 2013-05-01, Order Canceled/Margin/Rejected
# 2013-05-01, Order Canceled/Margin/Rejected
# 2013-05-02, Order Canceled/Margin/Rejected
# 2013-05-02, Order Canceled/Margin/Rejected
# 2013-05-03, Order Canceled/Margin/Rejected
# 2013-05-03, Order Canceled/Margin/Rejected
# 2013-05-06, Order Canceled/Margin/Rejected
# 2013-05-06, Order Canceled/Margin/Rejected
# 2013-05-07, Order Canceled/Margin/Rejected
# 2013-05-07, Order Canceled/Margin/Rejected
# 2013-05-08, Order Canceled/Margin/Rejected
# 2013-05-08, Order Canceled/Margin/Rejected
# 2013-05-09, Order Canceled/Margin/Rejected
# 2013-05-09, Order Canceled/Margin/Rejected
# 2013-05-10, Order Canceled/Margin/Rejected
# 2013-05-10, Order Canceled/Margin/Rejected
# 2013-05-13, Order Canceled/Margin/Rejected
# 2013-05-13, Order Canceled/Margin/Rejected
# 2013-05-14, Order Canceled/Margin/Rejected
# 2013-05-14, Order Canceled/Margin/Rejected
# 2013-05-15, Order Canceled/Margin/Rejected
# 2013-05-15, Order Canceled/Margin/Rejected
# 2013-05-16, Order Canceled/Margin/Rejected
# 2013-05-16, Order Canceled/Margin/Rejected
# 2013-05-17, Order Canceled/Margin/Rejected
# 2013-05-17, Order Canceled/Margin/Rejected
# 2013-05-20, Order Canceled/Margin/Rejected
# 2013-05-20, Order Canceled/Margin/Rejected
# 2013-05-21, Order Canceled/Margin/Rejected
# 2013-05-21, Order Canceled/Margin/Rejected
# 2013-05-22, Order Canceled/Margin/Rejected
# 2013-05-22, Order Canceled/Margin/Rejected
# 2013-05-23, Order Canceled/Margin/Rejected
# 2013-05-23, Order Canceled/Margin/Rejected
# 2013-05-24, Order Canceled/Margin/Rejected
# 2013-05-24, Order Canceled/Margin/Rejected
# 2013-05-28, Order Canceled/Margin/Rejected
# 2013-05-28, Order Canceled/Margin/Rejected
# 2013-05-29, Order Canceled/Margin/Rejected
# 2013-05-29, Order Canceled/Margin/Rejected
# 2013-05-30, Order Canceled/Margin/Rejected
# 2013-05-30, Order Canceled/Margin/Rejected
# 2013-05-31, Order Canceled/Margin/Rejected
# 2013-05-31, Order Canceled/Margin/Rejected
# 2013-06-03, Order Canceled/Margin/Rejected
# 2013-06-03, Order Canceled/Margin/Rejected
# 2013-06-04, Order Canceled/Margin/Rejected
# 2013-06-04, Order Canceled/Margin/Rejected
# 2013-06-05, Order Canceled/Margin/Rejected
# 2013-06-05, Order Canceled/Margin/Rejected
# 2013-06-06, Order Canceled/Margin/Rejected
# 2013-06-06, Order Canceled/Margin/Rejected
# 2013-06-07, Order Canceled/Margin/Rejected
# 2013-06-07, Order Canceled/Margin/Rejected
# 2013-06-10, Order Canceled/Margin/Rejected
# 2013-06-10, Order Canceled/Margin/Rejected
# 2013-06-11, Order Canceled/Margin/Rejected
# 2013-06-11, Order Canceled/Margin/Rejected
# 2013-06-12, Order Canceled/Margin/Rejected
# 2013-06-12, Order Canceled/Margin/Rejected
# 2013-06-13, Order Canceled/Margin/Rejected
# 2013-06-13, Order Canceled/Margin/Rejected
# 2013-06-14, Order Canceled/Margin/Rejected
# 2013-06-14, Order Canceled/Margin/Rejected
# 2013-06-17, Order Canceled/Margin/Rejected
# 2013-06-17, Order Canceled/Margin/Rejected
# 2013-06-18, Order Canceled/Margin/Rejected
# 2013-06-18, Order Canceled/Margin/Rejected
# 2013-06-19, Order Canceled/Margin/Rejected
# 2013-06-19, Order Canceled/Margin/Rejected
# 2013-06-20, Order Canceled/Margin/Rejected
# 2013-06-20, Order Canceled/Margin/Rejected
# 2013-06-21, Order Canceled/Margin/Rejected
# 2013-06-21, Order Canceled/Margin/Rejected
# 2013-06-24, Order Canceled/Margin/Rejected
# 2013-06-24, Order Canceled/Margin/Rejected
# 2013-06-25, Order Canceled/Margin/Rejected
# 2013-06-25, Order Canceled/Margin/Rejected
# 2013-06-26, Order Canceled/Margin/Rejected
# 2013-06-26, Order Canceled/Margin/Rejected
# 2013-06-27, Order Canceled/Margin/Rejected
# 2013-06-27, Order Canceled/Margin/Rejected
# 2013-06-28, Order Canceled/Margin/Rejected
# 2013-06-28, Order Canceled/Margin/Rejected
# 2013-07-01, Order Canceled/Margin/Rejected
# 2013-07-01, Order Canceled/Margin/Rejected
# 2013-07-02, Order Canceled/Margin/Rejected
# 2013-07-02, Order Canceled/Margin/Rejected
# 2013-07-03, Order Canceled/Margin/Rejected
# 2013-07-03, Order Canceled/Margin/Rejected
# 2013-07-05, Order Canceled/Margin/Rejected
# 2013-07-05, Order Canceled/Margin/Rejected
# 2013-07-08, Order Canceled/Margin/Rejected
# 2013-07-08, Order Canceled/Margin/Rejected
# 2013-07-09, Order Canceled/Margin/Rejected
# 2013-07-09, Order Canceled/Margin/Rejected
# 2013-07-10, Order Canceled/Margin/Rejected
# 2013-07-10, Order Canceled/Margin/Rejected
# 2013-07-11, Order Canceled/Margin/Rejected
# 2013-07-11, Order Canceled/Margin/Rejected
# 2013-07-12, Order Canceled/Margin/Rejected
# 2013-07-12, Order Canceled/Margin/Rejected
# 2013-07-15, Order Canceled/Margin/Rejected
# 2013-07-15, Order Canceled/Margin/Rejected
# 2013-07-16, Order Canceled/Margin/Rejected
# 2013-07-16, Order Canceled/Margin/Rejected
# 2013-07-17, Order Canceled/Margin/Rejected
# 2013-07-17, Order Canceled/Margin/Rejected
# 2013-07-18, Order Canceled/Margin/Rejected
# 2013-07-18, Order Canceled/Margin/Rejected
# 2013-07-19, Order Canceled/Margin/Rejected
# 2013-07-19, Order Canceled/Margin/Rejected
# 2013-07-22, Order Canceled/Margin/Rejected
# 2013-07-22, Order Canceled/Margin/Rejected
# 2013-07-23, Order Canceled/Margin/Rejected
# 2013-07-23, Order Canceled/Margin/Rejected
# 2013-07-24, Order Canceled/Margin/Rejected
# 2013-07-24, Order Canceled/Margin/Rejected
# 2013-07-25, Order Canceled/Margin/Rejected
# 2013-07-25, Order Canceled/Margin/Rejected
# 2013-07-26, Order Canceled/Margin/Rejected
# 2013-07-26, Order Canceled/Margin/Rejected
# 2013-07-29, Order Canceled/Margin/Rejected
# 2013-07-29, Order Canceled/Margin/Rejected
# 2013-07-30, Order Canceled/Margin/Rejected
# 2013-07-30, Order Canceled/Margin/Rejected
# 2013-07-31, Order Canceled/Margin/Rejected
# 2013-07-31, Order Canceled/Margin/Rejected
# 2013-08-01, Order Canceled/Margin/Rejected
# 2013-08-01, Order Canceled/Margin/Rejected
# 2013-08-02, Order Canceled/Margin/Rejected
# 2013-08-02, Order Canceled/Margin/Rejected
# 2013-08-05, Order Canceled/Margin/Rejected
# 2013-08-05, Order Canceled/Margin/Rejected
# 2013-08-06, Order Canceled/Margin/Rejected
# 2013-08-06, Order Canceled/Margin/Rejected
# 2013-08-07, Order Canceled/Margin/Rejected
# 2013-08-07, Order Canceled/Margin/Rejected
# 2013-08-08, Order Canceled/Margin/Rejected
# 2013-08-08, Order Canceled/Margin/Rejected
# 2013-08-09, Order Canceled/Margin/Rejected
# 2013-08-09, Order Canceled/Margin/Rejected
# 2013-08-12, Order Canceled/Margin/Rejected
# 2013-08-12, Order Canceled/Margin/Rejected
# 2013-08-13, Order Canceled/Margin/Rejected
# 2013-08-13, Order Canceled/Margin/Rejected
# 2013-08-14, Order Canceled/Margin/Rejected
# 2013-08-14, Order Canceled/Margin/Rejected
# 2013-08-15, Order Canceled/Margin/Rejected
# 2013-08-15, Order Canceled/Margin/Rejected
# 2013-08-16, Order Canceled/Margin/Rejected
# 2013-08-16, Order Canceled/Margin/Rejected
# 2013-08-19, Order Canceled/Margin/Rejected
# 2013-08-19, Order Canceled/Margin/Rejected
# 2013-08-20, Order Canceled/Margin/Rejected
# 2013-08-20, Order Canceled/Margin/Rejected
# 2013-08-21, Order Canceled/Margin/Rejected
# 2013-08-21, Order Canceled/Margin/Rejected
# 2013-08-22, Order Canceled/Margin/Rejected
# 2013-08-22, Order Canceled/Margin/Rejected
# 2013-08-23, Order Canceled/Margin/Rejected
# 2013-08-23, Order Canceled/Margin/Rejected
# 2013-08-26, Order Canceled/Margin/Rejected
# 2013-08-26, Order Canceled/Margin/Rejected
# 2013-08-27, Order Canceled/Margin/Rejected
# 2013-08-27, Order Canceled/Margin/Rejected
# 2013-08-28, Order Canceled/Margin/Rejected
# 2013-08-28, Order Canceled/Margin/Rejected
# 2013-08-29, Order Canceled/Margin/Rejected
# 2013-08-29, Order Canceled/Margin/Rejected
# 2013-08-30, Order Canceled/Margin/Rejected
# 2013-08-30, Order Canceled/Margin/Rejected
# 2013-09-03, Order Canceled/Margin/Rejected
# 2013-09-03, Order Canceled/Margin/Rejected
# 2013-09-04, Order Canceled/Margin/Rejected
# 2013-09-04, Order Canceled/Margin/Rejected
# 2013-09-05, Order Canceled/Margin/Rejected
# 2013-09-05, Order Canceled/Margin/Rejected
# 2013-09-06, Order Canceled/Margin/Rejected
# 2013-09-06, Order Canceled/Margin/Rejected
# 2013-09-09, Order Canceled/Margin/Rejected
# 2013-09-09, Order Canceled/Margin/Rejected
# 2013-09-10, Order Canceled/Margin/Rejected
# 2013-09-10, Order Canceled/Margin/Rejected
# 2013-09-11, Order Canceled/Margin/Rejected
# 2013-09-11, Order Canceled/Margin/Rejected
# 2013-09-12, Order Canceled/Margin/Rejected
# 2013-09-12, Order Canceled/Margin/Rejected
# 2013-09-13, Order Canceled/Margin/Rejected
# 2013-09-13, Order Canceled/Margin/Rejected
# 2013-09-16, Order Canceled/Margin/Rejected
# 2013-09-16, Order Canceled/Margin/Rejected
# 2013-09-17, Order Canceled/Margin/Rejected
# 2013-09-17, Order Canceled/Margin/Rejected
# 2013-09-18, Order Canceled/Margin/Rejected
# 2013-09-18, Order Canceled/Margin/Rejected
# 2013-09-19, Order Canceled/Margin/Rejected
# 2013-09-19, Order Canceled/Margin/Rejected
# 2013-09-20, Order Canceled/Margin/Rejected
# 2013-09-20, Order Canceled/Margin/Rejected
# 2013-09-23, Order Canceled/Margin/Rejected
# 2013-09-23, Order Canceled/Margin/Rejected
# 2013-09-24, Order Canceled/Margin/Rejected
# 2013-09-24, Order Canceled/Margin/Rejected
# 2013-09-25, Order Canceled/Margin/Rejected
# 2013-09-25, Order Canceled/Margin/Rejected
# 2013-09-26, Order Canceled/Margin/Rejected
# 2013-09-26, Order Canceled/Margin/Rejected
# 2013-09-27, Order Canceled/Margin/Rejected
# 2013-09-27, Order Canceled/Margin/Rejected
# 2013-09-30, Order Canceled/Margin/Rejected
# 2013-09-30, Order Canceled/Margin/Rejected
# 2013-10-01, Order Canceled/Margin/Rejected
# 2013-10-01, Order Canceled/Margin/Rejected
# 2013-10-02, Order Canceled/Margin/Rejected
# 2013-10-02, Order Canceled/Margin/Rejected
# 2013-10-03, Order Canceled/Margin/Rejected
# 2013-10-03, Order Canceled/Margin/Rejected
# 2013-10-04, Order Canceled/Margin/Rejected
# 2013-10-04, Order Canceled/Margin/Rejected
# 2013-10-07, Order Canceled/Margin/Rejected
# 2013-10-07, Order Canceled/Margin/Rejected
# 2013-10-08, Order Canceled/Margin/Rejected
# 2013-10-08, Order Canceled/Margin/Rejected
# 2013-10-09, Order Canceled/Margin/Rejected
# 2013-10-09, Order Canceled/Margin/Rejected
# 2013-10-10, Order Canceled/Margin/Rejected
# 2013-10-10, Order Canceled/Margin/Rejected
# 2013-10-11, Order Canceled/Margin/Rejected
# 2013-10-11, Order Canceled/Margin/Rejected
# 2013-10-14, Order Canceled/Margin/Rejected
# 2013-10-14, Order Canceled/Margin/Rejected
# 2013-10-15, Order Canceled/Margin/Rejected
# 2013-10-15, Order Canceled/Margin/Rejected
# 2013-10-16, Order Canceled/Margin/Rejected
# 2013-10-16, Order Canceled/Margin/Rejected
# 2013-10-17, Order Canceled/Margin/Rejected
# 2013-10-17, Order Canceled/Margin/Rejected
# 2013-10-18, Order Canceled/Margin/Rejected
# 2013-10-18, Order Canceled/Margin/Rejected
# 2013-10-21, Order Canceled/Margin/Rejected
# 2013-10-21, Order Canceled/Margin/Rejected
# 2013-10-22, Order Canceled/Margin/Rejected
# 2013-10-22, Order Canceled/Margin/Rejected
# 2013-10-23, Order Canceled/Margin/Rejected
# 2013-10-23, Order Canceled/Margin/Rejected
# 2013-10-24, Order Canceled/Margin/Rejected
# 2013-10-24, Order Canceled/Margin/Rejected
# 2013-10-25, Order Canceled/Margin/Rejected
# 2013-10-25, Order Canceled/Margin/Rejected
# 2013-10-28, Order Canceled/Margin/Rejected
# 2013-10-28, Order Canceled/Margin/Rejected
# 2013-10-29, Order Canceled/Margin/Rejected
# 2013-10-29, Order Canceled/Margin/Rejected
# 2013-10-30, Order Canceled/Margin/Rejected
# 2013-10-30, Order Canceled/Margin/Rejected
# 2013-10-31, Order Canceled/Margin/Rejected
# 2013-10-31, Order Canceled/Margin/Rejected
# 2013-11-01, Order Canceled/Margin/Rejected
# 2013-11-01, Order Canceled/Margin/Rejected
# 2013-11-04, Order Canceled/Margin/Rejected
# 2013-11-04, Order Canceled/Margin/Rejected
# 2013-11-05, Order Canceled/Margin/Rejected
# 2013-11-05, Order Canceled/Margin/Rejected
# 2013-11-06, Order Canceled/Margin/Rejected
# 2013-11-06, Order Canceled/Margin/Rejected
# 2013-11-07, Order Canceled/Margin/Rejected
# 2013-11-07, Order Canceled/Margin/Rejected
# 2013-11-08, Order Canceled/Margin/Rejected
# 2013-11-08, Order Canceled/Margin/Rejected
# 2013-11-11, Order Canceled/Margin/Rejected
# 2013-11-11, Order Canceled/Margin/Rejected
# 2013-11-12, Order Canceled/Margin/Rejected
# 2013-11-12, Order Canceled/Margin/Rejected
# 2013-11-13, Order Canceled/Margin/Rejected
# 2013-11-13, Order Canceled/Margin/Rejected
# 2013-11-14, Order Canceled/Margin/Rejected
# 2013-11-14, Order Canceled/Margin/Rejected
# 2013-11-15, Order Canceled/Margin/Rejected
# 2013-11-15, Order Canceled/Margin/Rejected
# 2013-11-18, Order Canceled/Margin/Rejected
# 2013-11-18, Order Canceled/Margin/Rejected
# 2013-11-19, Order Canceled/Margin/Rejected
# 2013-11-19, Order Canceled/Margin/Rejected
# 2013-11-20, Order Canceled/Margin/Rejected
# 2013-11-20, Order Canceled/Margin/Rejected
# 2013-11-21, Order Canceled/Margin/Rejected
# 2013-11-21, Order Canceled/Margin/Rejected
# 2013-11-22, Order Canceled/Margin/Rejected
# 2013-11-22, Order Canceled/Margin/Rejected
# 2013-11-25, Order Canceled/Margin/Rejected
# 2013-11-25, Order Canceled/Margin/Rejected
# 2013-11-26, Order Canceled/Margin/Rejected
# 2013-11-26, Order Canceled/Margin/Rejected
# 2013-11-27, Order Canceled/Margin/Rejected
# 2013-11-27, Order Canceled/Margin/Rejected
# 2013-11-29, Order Canceled/Margin/Rejected
# 2013-11-29, Order Canceled/Margin/Rejected
# 2013-12-02, Order Canceled/Margin/Rejected
# 2013-12-02, Order Canceled/Margin/Rejected
# 2013-12-03, Order Canceled/Margin/Rejected
# 2013-12-03, Order Canceled/Margin/Rejected
# 2013-12-04, Order Canceled/Margin/Rejected
# 2013-12-04, Order Canceled/Margin/Rejected
# 2013-12-05, Order Canceled/Margin/Rejected
# 2013-12-05, Order Canceled/Margin/Rejected
# 2013-12-06, Order Canceled/Margin/Rejected
# 2013-12-06, Order Canceled/Margin/Rejected
# 2013-12-09, Order Canceled/Margin/Rejected
# 2013-12-09, Order Canceled/Margin/Rejected
# 2013-12-10, Order Canceled/Margin/Rejected
# 2013-12-10, Order Canceled/Margin/Rejected
# 2013-12-11, Order Canceled/Margin/Rejected
# 2013-12-11, Order Canceled/Margin/Rejected
# 2013-12-12, Order Canceled/Margin/Rejected
# 2013-12-12, Order Canceled/Margin/Rejected
# 2013-12-13, Order Canceled/Margin/Rejected
# 2013-12-13, Order Canceled/Margin/Rejected
# 2013-12-16, Order Canceled/Margin/Rejected
# 2013-12-16, Order Canceled/Margin/Rejected
# 2013-12-17, Order Canceled/Margin/Rejected
# 2013-12-17, Order Canceled/Margin/Rejected
# 2013-12-18, Order Canceled/Margin/Rejected
# 2013-12-18, Order Canceled/Margin/Rejected
# 2013-12-19, Order Canceled/Margin/Rejected
# 2013-12-19, Order Canceled/Margin/Rejected
# 2013-12-20, Order Canceled/Margin/Rejected
# 2013-12-20, Order Canceled/Margin/Rejected
# 2013-12-23, Order Canceled/Margin/Rejected
# 2013-12-23, Order Canceled/Margin/Rejected
# 2013-12-24, Order Canceled/Margin/Rejected
# 2013-12-24, Order Canceled/Margin/Rejected
# 2013-12-26, Order Canceled/Margin/Rejected
# 2013-12-26, Order Canceled/Margin/Rejected
# 2013-12-27, Order Canceled/Margin/Rejected
# 2013-12-27, Order Canceled/Margin/Rejected
# 2013-12-30, Order Canceled/Margin/Rejected
# 2013-12-30, Order Canceled/Margin/Rejected
# 2013-12-31, Order Canceled/Margin/Rejected
# 2013-12-31, Order Canceled/Margin/Rejected
# 2014-01-02, Order Canceled/Margin/Rejected
# 2014-01-02, Order Canceled/Margin/Rejected
# 2014-01-03, Order Canceled/Margin/Rejected
# 2014-01-03, Order Canceled/Margin/Rejected
# 2014-01-06, Order Canceled/Margin/Rejected
# 2014-01-06, Order Canceled/Margin/Rejected
# 2014-01-07, Order Canceled/Margin/Rejected
# 2014-01-07, Order Canceled/Margin/Rejected
# 2014-01-08, Order Canceled/Margin/Rejected
# 2014-01-08, Order Canceled/Margin/Rejected
# 2014-01-09, Order Canceled/Margin/Rejected
# 2014-01-09, Order Canceled/Margin/Rejected
# 2014-01-10, Order Canceled/Margin/Rejected
# 2014-01-10, Order Canceled/Margin/Rejected
# 2014-01-13, Order Canceled/Margin/Rejected
# 2014-01-13, Order Canceled/Margin/Rejected
# 2014-01-14, Order Canceled/Margin/Rejected
# 2014-01-14, Order Canceled/Margin/Rejected
# 2014-01-15, Order Canceled/Margin/Rejected
# 2014-01-15, Order Canceled/Margin/Rejected
# 2014-01-16, Order Canceled/Margin/Rejected
# 2014-01-16, Order Canceled/Margin/Rejected
# 2014-01-17, Order Canceled/Margin/Rejected
# 2014-01-17, Order Canceled/Margin/Rejected
# 2014-01-21, Order Canceled/Margin/Rejected
# 2014-01-21, Order Canceled/Margin/Rejected
# 2014-01-22, Order Canceled/Margin/Rejected
# 2014-01-22, Order Canceled/Margin/Rejected
# 2014-01-23, Order Canceled/Margin/Rejected
# 2014-01-23, Order Canceled/Margin/Rejected
# 2014-01-24, Order Canceled/Margin/Rejected
# 2014-01-24, Order Canceled/Margin/Rejected
# 2014-01-27, Order Canceled/Margin/Rejected
# 2014-01-27, Order Canceled/Margin/Rejected
# 2014-01-28, Order Canceled/Margin/Rejected
# 2014-01-28, Order Canceled/Margin/Rejected
# 2014-01-29, Order Canceled/Margin/Rejected
# 2014-01-29, Order Canceled/Margin/Rejected
# 2014-01-30, Order Canceled/Margin/Rejected
# 2014-01-30, Order Canceled/Margin/Rejected
# 2014-01-31, Order Canceled/Margin/Rejected
# 2014-01-31, Order Canceled/Margin/Rejected
# 2014-02-03, Order Canceled/Margin/Rejected
# 2014-02-03, Order Canceled/Margin/Rejected
# 2014-02-04, Order Canceled/Margin/Rejected
# 2014-02-04, Order Canceled/Margin/Rejected
# 2014-02-05, Order Canceled/Margin/Rejected
# 2014-02-05, Order Canceled/Margin/Rejected
# 2014-02-06, Order Canceled/Margin/Rejected
# 2014-02-06, Order Canceled/Margin/Rejected
# 2014-02-07, Order Canceled/Margin/Rejected
# 2014-02-07, Order Canceled/Margin/Rejected
# 2014-02-10, Order Canceled/Margin/Rejected
# 2014-02-10, Order Canceled/Margin/Rejected
# 2014-02-11, Order Canceled/Margin/Rejected
# 2014-02-11, Order Canceled/Margin/Rejected
# 2014-02-12, Order Canceled/Margin/Rejected
# 2014-02-12, Order Canceled/Margin/Rejected
# 2014-02-13, Order Canceled/Margin/Rejected
# 2014-02-13, Order Canceled/Margin/Rejected
# 2014-02-14, Order Canceled/Margin/Rejected
# 2014-02-14, Order Canceled/Margin/Rejected
# 2014-02-18, Order Canceled/Margin/Rejected
# 2014-02-18, Order Canceled/Margin/Rejected
# 2014-02-19, Order Canceled/Margin/Rejected
# 2014-02-19, Order Canceled/Margin/Rejected
# 2014-02-20, Order Canceled/Margin/Rejected
# 2014-02-20, Order Canceled/Margin/Rejected
# 2014-02-21, Order Canceled/Margin/Rejected
# 2014-02-21, Order Canceled/Margin/Rejected
# 2014-02-24, Order Canceled/Margin/Rejected
# 2014-02-24, Order Canceled/Margin/Rejected
# 2014-02-25, Order Canceled/Margin/Rejected
# 2014-02-25, Order Canceled/Margin/Rejected
# 2014-02-26, Order Canceled/Margin/Rejected
# 2014-02-26, Order Canceled/Margin/Rejected
# 2014-02-27, Order Canceled/Margin/Rejected
# 2014-02-27, Order Canceled/Margin/Rejected
# 2014-02-28, Order Canceled/Margin/Rejected
# 2014-02-28, Order Canceled/Margin/Rejected
# 2014-03-03, Order Canceled/Margin/Rejected
# 2014-03-03, Order Canceled/Margin/Rejected
# 2014-03-04, Order Canceled/Margin/Rejected
# 2014-03-04, Order Canceled/Margin/Rejected
# 2014-03-05, Order Canceled/Margin/Rejected
# 2014-03-05, Order Canceled/Margin/Rejected
# 2014-03-06, Order Canceled/Margin/Rejected
# 2014-03-06, Order Canceled/Margin/Rejected
# 2014-03-07, Order Canceled/Margin/Rejected
# 2014-03-07, Order Canceled/Margin/Rejected
# 2014-03-10, Order Canceled/Margin/Rejected
# 2014-03-10, Order Canceled/Margin/Rejected
# 2014-03-11, Order Canceled/Margin/Rejected
# 2014-03-11, Order Canceled/Margin/Rejected
# 2014-03-12, Order Canceled/Margin/Rejected
# 2014-03-12, Order Canceled/Margin/Rejected
# 2014-03-13, Order Canceled/Margin/Rejected
# 2014-03-13, Order Canceled/Margin/Rejected
# 2014-03-14, Order Canceled/Margin/Rejected
# 2014-03-14, Order Canceled/Margin/Rejected
# 2014-03-17, Order Canceled/Margin/Rejected
# 2014-03-17, Order Canceled/Margin/Rejected
# 2014-03-18, Order Canceled/Margin/Rejected
# 2014-03-18, Order Canceled/Margin/Rejected
# 2014-03-19, Order Canceled/Margin/Rejected
# 2014-03-19, Order Canceled/Margin/Rejected
# 2014-03-20, Order Canceled/Margin/Rejected
# 2014-03-20, Order Canceled/Margin/Rejected
# 2014-03-21, Order Canceled/Margin/Rejected
# 2014-03-21, Order Canceled/Margin/Rejected
# 2014-03-24, Order Canceled/Margin/Rejected
# 2014-03-24, Order Canceled/Margin/Rejected
# 2014-03-25, Order Canceled/Margin/Rejected
# 2014-03-25, Order Canceled/Margin/Rejected
# 2014-03-26, Order Canceled/Margin/Rejected
# 2014-03-26, Order Canceled/Margin/Rejected
# 2014-03-27, Order Canceled/Margin/Rejected
# 2014-03-27, Order Canceled/Margin/Rejected
# 2014-03-28, Order Canceled/Margin/Rejected
# 2014-03-28, Order Canceled/Margin/Rejected
# 2014-03-31, Order Canceled/Margin/Rejected
# 2014-03-31, Order Canceled/Margin/Rejected
# 2014-04-01, Order Canceled/Margin/Rejected
# 2014-04-02, Order Canceled/Margin/Rejected
# 2014-04-03, Order Canceled/Margin/Rejected
# 2014-04-04, Order Canceled/Margin/Rejected
# 2014-04-07, Order Canceled/Margin/Rejected
# 2014-04-08, Order Canceled/Margin/Rejected
# 2014-04-09, Order Canceled/Margin/Rejected
# 2014-04-10, Order Canceled/Margin/Rejected
# 2014-04-11, Order Canceled/Margin/Rejected
# 2014-04-14, Order Canceled/Margin/Rejected
# 2014-04-15, Order Canceled/Margin/Rejected
# 2014-04-16, Order Canceled/Margin/Rejected
# 2014-08-04, Order Canceled/Margin/Rejected
# 2014-08-06, Order Canceled/Margin/Rejected
# 2014-08-07, Order Canceled/Margin/Rejected
# 2014-08-08, Order Canceled/Margin/Rejected
# 2014-08-11, Order Canceled/Margin/Rejected
# 2014-08-12, Order Canceled/Margin/Rejected
# 2014-08-13, Order Canceled/Margin/Rejected
# 2014-08-14, Order Canceled/Margin/Rejected
# 2014-08-15, Order Canceled/Margin/Rejected
# 2014-08-18, Order Canceled/Margin/Rejected
# 2014-08-19, Order Canceled/Margin/Rejected
# 2014-08-20, Order Canceled/Margin/Rejected
# 2014-08-21, Order Canceled/Margin/Rejected
# 2014-08-22, Order Canceled/Margin/Rejected
# 2014-08-25, Order Canceled/Margin/Rejected
# 2014-08-26, Order Canceled/Margin/Rejected
# 2014-08-29, Order Canceled/Margin/Rejected
# 2014-09-02, Order Canceled/Margin/Rejected
# 2014-09-03, Order Canceled/Margin/Rejected
# 2014-09-09, Order Canceled/Margin/Rejected
# 2014-09-10, Order Canceled/Margin/Rejected
# 2014-09-11, Order Canceled/Margin/Rejected
# 2014-09-12, Order Canceled/Margin/Rejected
# 2014-09-15, Order Canceled/Margin/Rejected
# 2014-09-16, Order Canceled/Margin/Rejected
# 2014-09-17, Order Canceled/Margin/Rejected
# 2014-09-18, Order Canceled/Margin/Rejected
# 2014-09-19, Order Canceled/Margin/Rejected
# 2014-09-22, Order Canceled/Margin/Rejected
# 2014-09-23, Order Canceled/Margin/Rejected
# 2014-09-24, Order Canceled/Margin/Rejected
# 2014-09-25, Order Canceled/Margin/Rejected
# 2014-09-26, Order Canceled/Margin/Rejected
# 2014-09-29, Order Canceled/Margin/Rejected
# 2014-09-30, Order Canceled/Margin/Rejected
# 2014-10-01, Order Canceled/Margin/Rejected
# 2014-10-02, Order Canceled/Margin/Rejected
# 2014-10-03, Order Canceled/Margin/Rejected
# 2014-10-03, Order Canceled/Margin/Rejected
# 2014-10-06, Order Canceled/Margin/Rejected
# 2014-10-06, Order Canceled/Margin/Rejected
# 2014-10-07, Order Canceled/Margin/Rejected
# 2014-10-07, Order Canceled/Margin/Rejected
# 2014-10-08, Order Canceled/Margin/Rejected
# 2014-10-08, Order Canceled/Margin/Rejected
# 2014-10-09, Order Canceled/Margin/Rejected
# 2014-10-09, Order Canceled/Margin/Rejected
# 2014-10-10, Order Canceled/Margin/Rejected
# 2014-10-10, Order Canceled/Margin/Rejected
# 2014-10-13, Order Canceled/Margin/Rejected
# 2014-10-13, Order Canceled/Margin/Rejected
# 2014-10-14, Order Canceled/Margin/Rejected
# 2014-10-14, Order Canceled/Margin/Rejected
# 2014-10-15, Order Canceled/Margin/Rejected
# 2014-10-15, Order Canceled/Margin/Rejected
# 2014-10-16, Order Canceled/Margin/Rejected
# 2014-10-16, Order Canceled/Margin/Rejected
# 2014-10-17, Order Canceled/Margin/Rejected
# 2014-10-17, Order Canceled/Margin/Rejected
# 2014-10-20, Order Canceled/Margin/Rejected
# 2014-10-20, Order Canceled/Margin/Rejected
# 2014-10-21, Order Canceled/Margin/Rejected
# 2014-10-21, Order Canceled/Margin/Rejected
# 2014-10-22, Order Canceled/Margin/Rejected
# 2014-10-22, Order Canceled/Margin/Rejected
# 2014-10-23, Order Canceled/Margin/Rejected
# 2014-10-23, Order Canceled/Margin/Rejected
# 2014-10-24, Order Canceled/Margin/Rejected
# 2014-10-24, Order Canceled/Margin/Rejected
# 2014-10-27, Order Canceled/Margin/Rejected
# 2014-10-27, Order Canceled/Margin/Rejected
# 2014-10-28, Order Canceled/Margin/Rejected
# 2014-10-28, Order Canceled/Margin/Rejected
# 2014-10-29, Order Canceled/Margin/Rejected
# 2014-10-29, Order Canceled/Margin/Rejected
# 2014-10-30, Order Canceled/Margin/Rejected
# 2014-10-30, Order Canceled/Margin/Rejected
# 2014-10-31, Order Canceled/Margin/Rejected
# 2014-10-31, Order Canceled/Margin/Rejected
# 2014-11-03, Order Canceled/Margin/Rejected
# 2014-11-04, Order Canceled/Margin/Rejected
# 2014-11-05, Order Canceled/Margin/Rejected
# 2014-11-05, Order Canceled/Margin/Rejected
# 2014-11-06, Order Canceled/Margin/Rejected
# 2014-11-06, Order Canceled/Margin/Rejected
# 2014-11-07, Order Canceled/Margin/Rejected
# 2014-11-07, Order Canceled/Margin/Rejected
# 2014-11-10, Order Canceled/Margin/Rejected
# 2014-11-10, Order Canceled/Margin/Rejected
# 2014-11-11, Order Canceled/Margin/Rejected
# 2014-11-11, Order Canceled/Margin/Rejected
# 2014-11-12, Order Canceled/Margin/Rejected
# 2014-11-12, Order Canceled/Margin/Rejected
# 2014-11-13, Order Canceled/Margin/Rejected
# 2014-11-13, Order Canceled/Margin/Rejected
# 2014-11-14, Order Canceled/Margin/Rejected
# 2014-11-14, Order Canceled/Margin/Rejected
# 2014-11-14, Order Canceled/Margin/Rejected
# 2014-11-17, Order Canceled/Margin/Rejected
# 2014-11-17, Order Canceled/Margin/Rejected
# 2014-11-17, Order Canceled/Margin/Rejected
# 2014-11-18, Order Canceled/Margin/Rejected
# 2014-11-18, Order Canceled/Margin/Rejected
# 2014-11-18, Order Canceled/Margin/Rejected
# 2014-11-19, Order Canceled/Margin/Rejected
# 2014-11-19, Order Canceled/Margin/Rejected
# 2014-11-19, Order Canceled/Margin/Rejected
# 2014-11-20, Order Canceled/Margin/Rejected
# 2014-11-20, Order Canceled/Margin/Rejected
# 2014-11-21, Order Canceled/Margin/Rejected
# 2014-11-21, Order Canceled/Margin/Rejected
# 2014-11-24, Order Canceled/Margin/Rejected
# 2014-11-24, Order Canceled/Margin/Rejected
# 2014-11-25, Order Canceled/Margin/Rejected
# 2014-11-25, Order Canceled/Margin/Rejected
# 2014-11-26, Order Canceled/Margin/Rejected
# 2014-11-26, Order Canceled/Margin/Rejected
# 2014-11-28, Order Canceled/Margin/Rejected
# 2014-11-28, Order Canceled/Margin/Rejected
# 2014-12-01, Order Canceled/Margin/Rejected
# 2014-12-01, Order Canceled/Margin/Rejected
# 2014-12-01, Order Canceled/Margin/Rejected
# 2014-12-02, Order Canceled/Margin/Rejected
# 2014-12-02, Order Canceled/Margin/Rejected
# 2014-12-02, Order Canceled/Margin/Rejected
# 2014-12-03, Order Canceled/Margin/Rejected
# 2014-12-03, Order Canceled/Margin/Rejected
# 2014-12-03, Order Canceled/Margin/Rejected
# 2014-12-04, Order Canceled/Margin/Rejected
# 2014-12-04, Order Canceled/Margin/Rejected
# 2014-12-04, Order Canceled/Margin/Rejected
# 2014-12-05, Order Canceled/Margin/Rejected
# 2014-12-05, Order Canceled/Margin/Rejected
# 2014-12-05, Order Canceled/Margin/Rejected
# 2014-12-08, Order Canceled/Margin/Rejected
# 2014-12-08, Order Canceled/Margin/Rejected
# 2014-12-08, Order Canceled/Margin/Rejected
# 2014-12-09, Order Canceled/Margin/Rejected
# 2014-12-09, Order Canceled/Margin/Rejected
# 2014-12-09, Order Canceled/Margin/Rejected
# 2014-12-10, Order Canceled/Margin/Rejected
# 2014-12-10, Order Canceled/Margin/Rejected
# 2014-12-10, Order Canceled/Margin/Rejected
# 2014-12-11, Order Canceled/Margin/Rejected
# 2014-12-11, Order Canceled/Margin/Rejected
# 2014-12-11, Order Canceled/Margin/Rejected
# 2014-12-12, Order Canceled/Margin/Rejected
# 2014-12-12, Order Canceled/Margin/Rejected
# 2014-12-12, Order Canceled/Margin/Rejected
# 2014-12-15, Order Canceled/Margin/Rejected
# 2014-12-15, Order Canceled/Margin/Rejected
# 2014-12-15, Order Canceled/Margin/Rejected
# 2014-12-16, Order Canceled/Margin/Rejected
# 2014-12-16, Order Canceled/Margin/Rejected
# 2014-12-16, Order Canceled/Margin/Rejected
# 2014-12-17, Order Canceled/Margin/Rejected
# 2014-12-17, Order Canceled/Margin/Rejected
# 2014-12-17, Order Canceled/Margin/Rejected
# 2014-12-18, Order Canceled/Margin/Rejected
# 2014-12-18, Order Canceled/Margin/Rejected
# 2014-12-18, Order Canceled/Margin/Rejected
# 2014-12-19, Order Canceled/Margin/Rejected
# 2014-12-19, Order Canceled/Margin/Rejected
# 2014-12-19, Order Canceled/Margin/Rejected
# 2014-12-22, Order Canceled/Margin/Rejected
# 2014-12-22, Order Canceled/Margin/Rejected
# 2014-12-22, Order Canceled/Margin/Rejected
# 2014-12-23, Order Canceled/Margin/Rejected
# 2014-12-23, Order Canceled/Margin/Rejected
# 2014-12-23, Order Canceled/Margin/Rejected
# 2014-12-24, Order Canceled/Margin/Rejected
# 2014-12-24, Order Canceled/Margin/Rejected
# 2014-12-24, Order Canceled/Margin/Rejected
# 2014-12-26, Order Canceled/Margin/Rejected
# 2014-12-26, Order Canceled/Margin/Rejected
# 2014-12-26, Order Canceled/Margin/Rejected
# 2014-12-29, Order Canceled/Margin/Rejected
# 2014-12-29, Order Canceled/Margin/Rejected
# 2014-12-29, Order Canceled/Margin/Rejected
# 2014-12-30, Order Canceled/Margin/Rejected
# 2014-12-30, Order Canceled/Margin/Rejected
# 2014-12-30, Order Canceled/Margin/Rejected
# 2014-12-31, Order Canceled/Margin/Rejected
# 2014-12-31, Order Canceled/Margin/Rejected
# 2014-12-31, Order Canceled/Margin/Rejected
# 2015-01-02, Order Canceled/Margin/Rejected
# 2015-01-02, Order Canceled/Margin/Rejected
# 2015-01-02, Order Canceled/Margin/Rejected
# 2015-01-05, Order Canceled/Margin/Rejected
# 2015-01-05, Order Canceled/Margin/Rejected
# 2015-01-05, Order Canceled/Margin/Rejected
# 2015-01-06, Order Canceled/Margin/Rejected
# 2015-01-06, Order Canceled/Margin/Rejected
# 2015-01-06, Order Canceled/Margin/Rejected
# 2015-01-07, Order Canceled/Margin/Rejected
# 2015-01-07, Order Canceled/Margin/Rejected
# 2015-01-07, Order Canceled/Margin/Rejected
# 2015-01-08, Order Canceled/Margin/Rejected
# 2015-01-08, Order Canceled/Margin/Rejected
# 2015-01-08, Order Canceled/Margin/Rejected
# 2015-01-09, Order Canceled/Margin/Rejected
# 2015-01-09, Order Canceled/Margin/Rejected
# 2015-01-09, Order Canceled/Margin/Rejected
# 2015-01-12, Order Canceled/Margin/Rejected
# 2015-01-12, Order Canceled/Margin/Rejected
# 2015-01-12, Order Canceled/Margin/Rejected
# 2015-01-13, Order Canceled/Margin/Rejected
# 2015-01-13, Order Canceled/Margin/Rejected
# 2015-01-13, Order Canceled/Margin/Rejected
# 2015-01-14, Order Canceled/Margin/Rejected
# 2015-01-14, Order Canceled/Margin/Rejected
# 2015-01-14, Order Canceled/Margin/Rejected
# 2015-01-15, Order Canceled/Margin/Rejected
# 2015-01-15, Order Canceled/Margin/Rejected
# 2015-01-15, Order Canceled/Margin/Rejected
# 2015-01-16, Order Canceled/Margin/Rejected
# 2015-01-16, Order Canceled/Margin/Rejected
# 2015-01-16, Order Canceled/Margin/Rejected
# 2015-01-20, Order Canceled/Margin/Rejected
# 2015-01-20, Order Canceled/Margin/Rejected
# 2015-01-20, Order Canceled/Margin/Rejected
# 2015-01-21, Order Canceled/Margin/Rejected
# 2015-01-21, Order Canceled/Margin/Rejected
# 2015-01-22, Order Canceled/Margin/Rejected
# 2015-01-22, Order Canceled/Margin/Rejected
# 2015-01-23, Order Canceled/Margin/Rejected
# 2015-01-23, Order Canceled/Margin/Rejected
# 2015-01-26, Order Canceled/Margin/Rejected
# 2015-01-26, Order Canceled/Margin/Rejected
# 2015-01-27, Order Canceled/Margin/Rejected
# 2015-01-27, Order Canceled/Margin/Rejected
# 2015-01-28, Order Canceled/Margin/Rejected
# 2015-01-28, Order Canceled/Margin/Rejected
# 2015-01-29, Order Canceled/Margin/Rejected
# 2015-01-29, Order Canceled/Margin/Rejected
# 2015-01-30, Order Canceled/Margin/Rejected
# 2015-01-30, Order Canceled/Margin/Rejected
# 2015-02-02, Order Canceled/Margin/Rejected
# 2015-02-02, Order Canceled/Margin/Rejected
# 2015-02-03, Order Canceled/Margin/Rejected
# 2015-02-03, Order Canceled/Margin/Rejected
# 2015-02-04, Order Canceled/Margin/Rejected
# 2015-02-04, Order Canceled/Margin/Rejected
# 2015-02-05, Order Canceled/Margin/Rejected
# 2015-02-05, Order Canceled/Margin/Rejected
# 2015-02-06, Order Canceled/Margin/Rejected
# 2015-02-06, Order Canceled/Margin/Rejected
# 2015-02-09, Order Canceled/Margin/Rejected
# 2015-02-09, Order Canceled/Margin/Rejected
# 2015-02-10, Order Canceled/Margin/Rejected
# 2015-02-10, Order Canceled/Margin/Rejected
# 2015-02-11, Order Canceled/Margin/Rejected
# 2015-02-11, Order Canceled/Margin/Rejected
# 2015-02-12, Order Canceled/Margin/Rejected
# 2015-02-12, Order Canceled/Margin/Rejected
# 2015-02-13, Order Canceled/Margin/Rejected
# 2015-02-13, Order Canceled/Margin/Rejected
# 2015-02-17, Order Canceled/Margin/Rejected
# 2015-02-17, Order Canceled/Margin/Rejected
# 2015-02-18, Order Canceled/Margin/Rejected
# 2015-02-18, Order Canceled/Margin/Rejected
# 2015-02-19, Order Canceled/Margin/Rejected
# 2015-02-19, Order Canceled/Margin/Rejected
# 2015-02-20, Order Canceled/Margin/Rejected
# 2015-02-20, Order Canceled/Margin/Rejected
# 2015-02-23, Order Canceled/Margin/Rejected
# 2015-02-23, Order Canceled/Margin/Rejected
# 2015-02-24, Order Canceled/Margin/Rejected
# 2015-02-24, Order Canceled/Margin/Rejected
# 2015-02-25, Order Canceled/Margin/Rejected
# 2015-02-25, Order Canceled/Margin/Rejected
# 2015-02-26, Order Canceled/Margin/Rejected
# 2015-02-27, Order Canceled/Margin/Rejected
# 2015-03-02, Order Canceled/Margin/Rejected
# 2015-03-03, Order Canceled/Margin/Rejected
# 2015-03-04, Order Canceled/Margin/Rejected
# 2015-03-05, Order Canceled/Margin/Rejected
# 2015-03-06, Order Canceled/Margin/Rejected
# 2015-03-09, Order Canceled/Margin/Rejected
# 2015-03-10, Order Canceled/Margin/Rejected
# 2015-03-11, Order Canceled/Margin/Rejected
# 2015-03-12, Order Canceled/Margin/Rejected
# 2015-03-13, Order Canceled/Margin/Rejected
# 2015-03-16, Order Canceled/Margin/Rejected
# 2015-03-17, Order Canceled/Margin/Rejected
# 2015-03-18, Order Canceled/Margin/Rejected
# 2015-03-19, Order Canceled/Margin/Rejected
# 2015-03-20, Order Canceled/Margin/Rejected
# 2015-03-23, Order Canceled/Margin/Rejected
# 2015-03-24, Order Canceled/Margin/Rejected
# 2015-03-25, Order Canceled/Margin/Rejected
# 2015-03-26, Order Canceled/Margin/Rejected
# 2015-03-27, Order Canceled/Margin/Rejected
# 2015-03-30, Order Canceled/Margin/Rejected
# 2015-03-31, Order Canceled/Margin/Rejected
# 2015-04-01, Order Canceled/Margin/Rejected
# 2015-04-02, Order Canceled/Margin/Rejected
# 2015-04-06, Order Canceled/Margin/Rejected
# 2015-04-07, Order Canceled/Margin/Rejected
# 2015-04-08, Order Canceled/Margin/Rejected
# 2015-04-09, Order Canceled/Margin/Rejected
# 2015-04-10, Order Canceled/Margin/Rejected
# 2015-04-13, Order Canceled/Margin/Rejected
# 2015-04-14, Order Canceled/Margin/Rejected
# 2015-04-15, Order Canceled/Margin/Rejected
# 2015-04-16, Order Canceled/Margin/Rejected
# 2015-04-17, Order Canceled/Margin/Rejected
# 2015-04-20, Order Canceled/Margin/Rejected
# 2015-04-21, Order Canceled/Margin/Rejected
# 2015-04-22, Order Canceled/Margin/Rejected
# 2015-04-23, Order Canceled/Margin/Rejected
# 2015-04-24, Order Canceled/Margin/Rejected
# 2015-04-27, Order Canceled/Margin/Rejected
# 2015-04-28, Order Canceled/Margin/Rejected
# 2015-04-29, Order Canceled/Margin/Rejected
# 2015-04-30, Order Canceled/Margin/Rejected
# 2015-05-01, Order Canceled/Margin/Rejected
# 2015-05-04, Order Canceled/Margin/Rejected
# 2015-05-05, Order Canceled/Margin/Rejected
# 2015-05-06, Order Canceled/Margin/Rejected
# 2015-05-07, Order Canceled/Margin/Rejected
# 2015-05-08, Order Canceled/Margin/Rejected
# 2015-05-11, Order Canceled/Margin/Rejected
# 2015-05-12, Order Canceled/Margin/Rejected
# 2015-05-13, Order Canceled/Margin/Rejected
# 2015-05-14, Order Canceled/Margin/Rejected
# 2015-05-15, Order Canceled/Margin/Rejected
# 2015-05-18, Order Canceled/Margin/Rejected
# 2015-05-19, Order Canceled/Margin/Rejected
# 2015-05-20, Order Canceled/Margin/Rejected
# 2015-05-21, Order Canceled/Margin/Rejected
# 2015-05-22, Order Canceled/Margin/Rejected
# 2015-05-26, Order Canceled/Margin/Rejected
# 2015-05-27, Order Canceled/Margin/Rejected
# 2015-05-28, Order Canceled/Margin/Rejected
# 2015-05-29, Order Canceled/Margin/Rejected
# 2015-06-01, Order Canceled/Margin/Rejected
# 2015-06-02, Order Canceled/Margin/Rejected
# 2015-06-03, Order Canceled/Margin/Rejected
# 2015-06-04, Order Canceled/Margin/Rejected
# 2015-06-05, Order Canceled/Margin/Rejected
# 2015-06-08, Order Canceled/Margin/Rejected
# 2015-06-09, Order Canceled/Margin/Rejected
# 2015-06-10, Order Canceled/Margin/Rejected
# 2015-06-11, Order Canceled/Margin/Rejected
# 2015-06-12, Order Canceled/Margin/Rejected
# 2015-06-15, Order Canceled/Margin/Rejected
# 2015-06-16, Order Canceled/Margin/Rejected
# 2015-06-17, Order Canceled/Margin/Rejected
# 2015-06-18, Order Canceled/Margin/Rejected
# 2015-06-19, Order Canceled/Margin/Rejected
# 2015-06-22, Order Canceled/Margin/Rejected
# 2015-06-23, Order Canceled/Margin/Rejected
# 2015-06-24, Order Canceled/Margin/Rejected
# 2015-06-25, Order Canceled/Margin/Rejected
# 2015-06-26, Order Canceled/Margin/Rejected
# 2015-06-29, Order Canceled/Margin/Rejected
# 2015-06-30, Order Canceled/Margin/Rejected
# 2015-07-01, Order Canceled/Margin/Rejected
# 2015-07-02, Order Canceled/Margin/Rejected
# 2015-07-06, Order Canceled/Margin/Rejected
# 2015-07-07, Order Canceled/Margin/Rejected
# 2015-07-08, Order Canceled/Margin/Rejected
# 2015-07-09, Order Canceled/Margin/Rejected
# 2015-07-10, Order Canceled/Margin/Rejected
# 2015-07-13, Order Canceled/Margin/Rejected
# 2015-07-14, Order Canceled/Margin/Rejected
# 2015-07-15, Order Canceled/Margin/Rejected
# 2015-07-16, Order Canceled/Margin/Rejected
# 2015-07-17, Order Canceled/Margin/Rejected
# 2015-07-20, Order Canceled/Margin/Rejected
# 2015-07-21, Order Canceled/Margin/Rejected
# 2015-07-22, Order Canceled/Margin/Rejected
# 2015-07-23, Order Canceled/Margin/Rejected
# 2015-07-24, Order Canceled/Margin/Rejected
# 2015-07-27, Order Canceled/Margin/Rejected
# 2015-07-28, Order Canceled/Margin/Rejected
# 2015-07-29, Order Canceled/Margin/Rejected
# 2015-07-30, Order Canceled/Margin/Rejected
# 2015-07-31, Order Canceled/Margin/Rejected
# 2015-07-31, Order Canceled/Margin/Rejected
# 2015-08-03, Order Canceled/Margin/Rejected
# 2015-08-04, Order Canceled/Margin/Rejected
# 2015-08-05, Order Canceled/Margin/Rejected
# 2015-08-06, Order Canceled/Margin/Rejected
# 2015-08-07, Order Canceled/Margin/Rejected
# 2015-08-10, Order Canceled/Margin/Rejected
# 2015-08-11, Order Canceled/Margin/Rejected
# 2015-08-12, Order Canceled/Margin/Rejected
# 2015-08-13, Order Canceled/Margin/Rejected
# 2015-08-14, Order Canceled/Margin/Rejected
# 2015-08-17, Order Canceled/Margin/Rejected
# 2015-08-17, Order Canceled/Margin/Rejected
# 2015-08-18, Order Canceled/Margin/Rejected
# 2015-08-18, Order Canceled/Margin/Rejected
# 2015-08-19, Order Canceled/Margin/Rejected
# 2015-08-19, Order Canceled/Margin/Rejected
# 2015-08-20, Order Canceled/Margin/Rejected
# 2015-08-20, Order Canceled/Margin/Rejected
# 2015-08-21, Order Canceled/Margin/Rejected
# 2015-08-21, Order Canceled/Margin/Rejected
# 2015-08-24, Order Canceled/Margin/Rejected
# 2015-08-24, Order Canceled/Margin/Rejected
# 2015-08-25, Order Canceled/Margin/Rejected
# 2015-08-25, Order Canceled/Margin/Rejected
# 2015-08-26, Order Canceled/Margin/Rejected
# 2015-08-26, Order Canceled/Margin/Rejected
# 2015-08-26, Order Canceled/Margin/Rejected
# 2015-08-27, Order Canceled/Margin/Rejected
# 2015-08-27, Order Canceled/Margin/Rejected
# 2015-08-28, Order Canceled/Margin/Rejected
# 2015-08-28, Order Canceled/Margin/Rejected
# 2015-08-31, Order Canceled/Margin/Rejected
# 2015-08-31, Order Canceled/Margin/Rejected
# 2015-09-01, Order Canceled/Margin/Rejected
# 2015-09-01, Order Canceled/Margin/Rejected
# 2015-09-02, Order Canceled/Margin/Rejected
# 2015-09-02, Order Canceled/Margin/Rejected
# 2015-09-03, Order Canceled/Margin/Rejected
# 2015-09-03, Order Canceled/Margin/Rejected
# 2015-09-04, Order Canceled/Margin/Rejected
# 2015-09-04, Order Canceled/Margin/Rejected
# 2015-09-08, Order Canceled/Margin/Rejected
# 2015-09-08, Order Canceled/Margin/Rejected
# 2015-09-09, Order Canceled/Margin/Rejected
# 2015-09-09, Order Canceled/Margin/Rejected
# 2015-09-10, Order Canceled/Margin/Rejected
# 2015-09-10, Order Canceled/Margin/Rejected
# 2015-09-11, Order Canceled/Margin/Rejected
# 2015-09-11, Order Canceled/Margin/Rejected
# 2015-09-14, Order Canceled/Margin/Rejected
# 2015-09-14, Order Canceled/Margin/Rejected
# 2015-09-15, Order Canceled/Margin/Rejected
# 2015-09-15, Order Canceled/Margin/Rejected
# 2015-09-16, Order Canceled/Margin/Rejected
# 2015-09-16, Order Canceled/Margin/Rejected
# 2015-09-17, Order Canceled/Margin/Rejected
# 2015-09-17, Order Canceled/Margin/Rejected
# 2015-09-18, Order Canceled/Margin/Rejected
# 2015-09-18, Order Canceled/Margin/Rejected
# 2015-09-21, Order Canceled/Margin/Rejected
# 2015-09-21, Order Canceled/Margin/Rejected
# 2015-09-22, Order Canceled/Margin/Rejected
# 2015-09-22, Order Canceled/Margin/Rejected
# 2015-09-23, Order Canceled/Margin/Rejected
# 2015-09-23, Order Canceled/Margin/Rejected
# 2015-09-24, Order Canceled/Margin/Rejected
# 2015-09-24, Order Canceled/Margin/Rejected
# 2015-09-25, Order Canceled/Margin/Rejected
# 2015-09-25, Order Canceled/Margin/Rejected
# 2015-09-28, Order Canceled/Margin/Rejected
# 2015-09-28, Order Canceled/Margin/Rejected
# 2015-09-29, Order Canceled/Margin/Rejected
# 2015-09-29, Order Canceled/Margin/Rejected
# 2015-09-30, Order Canceled/Margin/Rejected
# 2015-09-30, Order Canceled/Margin/Rejected
# 2015-10-01, Order Canceled/Margin/Rejected
# 2015-10-01, Order Canceled/Margin/Rejected
# 2015-10-02, Order Canceled/Margin/Rejected
# 2015-10-02, Order Canceled/Margin/Rejected
# 2015-10-05, Order Canceled/Margin/Rejected
# 2015-10-05, Order Canceled/Margin/Rejected
# 2015-10-06, Order Canceled/Margin/Rejected
# 2015-10-06, Order Canceled/Margin/Rejected
# 2015-10-07, Order Canceled/Margin/Rejected
# 2015-10-07, Order Canceled/Margin/Rejected
# 2015-10-08, Order Canceled/Margin/Rejected
# 2015-10-08, Order Canceled/Margin/Rejected
# 2015-10-09, Order Canceled/Margin/Rejected
# 2015-10-12, Order Canceled/Margin/Rejected
# 2015-10-13, Order Canceled/Margin/Rejected
# 2015-10-14, Order Canceled/Margin/Rejected
# 2015-10-14, Order Canceled/Margin/Rejected
# 2015-10-15, Order Canceled/Margin/Rejected
# 2015-10-15, Order Canceled/Margin/Rejected
# 2015-10-16, Order Canceled/Margin/Rejected
# 2015-10-16, Order Canceled/Margin/Rejected
# 2015-10-19, Order Canceled/Margin/Rejected
# 2015-10-20, Order Canceled/Margin/Rejected
# 2015-10-20, Order Canceled/Margin/Rejected
# 2015-10-21, Order Canceled/Margin/Rejected
# 2015-10-21, Order Canceled/Margin/Rejected
# 2015-10-22, Order Canceled/Margin/Rejected
# 2015-10-22, Order Canceled/Margin/Rejected
# 2015-10-23, Order Canceled/Margin/Rejected
# 2015-10-26, Order Canceled/Margin/Rejected
# 2015-10-27, Order Canceled/Margin/Rejected
# 2015-10-28, Order Canceled/Margin/Rejected
# 2015-10-29, Order Canceled/Margin/Rejected
# 2015-10-30, Order Canceled/Margin/Rejected
# 2015-11-02, Order Canceled/Margin/Rejected
# 2015-11-03, Order Canceled/Margin/Rejected
# 2015-11-04, Order Canceled/Margin/Rejected
# 2015-11-05, Order Canceled/Margin/Rejected
# 2015-11-06, Order Canceled/Margin/Rejected
# 2015-11-09, Order Canceled/Margin/Rejected
# 2015-11-10, Order Canceled/Margin/Rejected
# 2015-11-11, Order Canceled/Margin/Rejected
# 2015-11-12, Order Canceled/Margin/Rejected
# 2015-11-13, Order Canceled/Margin/Rejected
# 2015-11-16, Order Canceled/Margin/Rejected
# 2015-11-17, Order Canceled/Margin/Rejected
# 2015-11-18, Order Canceled/Margin/Rejected
# 2015-11-19, Order Canceled/Margin/Rejected
# 2015-11-20, Order Canceled/Margin/Rejected
# 2015-11-23, Order Canceled/Margin/Rejected
# 2015-11-24, Order Canceled/Margin/Rejected
# 2015-11-25, Order Canceled/Margin/Rejected
# 2015-11-27, Order Canceled/Margin/Rejected
# 2015-11-30, Order Canceled/Margin/Rejected
# 2015-12-01, Order Canceled/Margin/Rejected
# 2015-12-02, Order Canceled/Margin/Rejected
# 2015-12-02, Order Canceled/Margin/Rejected
# 2015-12-03, Order Canceled/Margin/Rejected
# 2015-12-03, Order Canceled/Margin/Rejected
# 2015-12-04, Order Canceled/Margin/Rejected
# 2015-12-04, Order Canceled/Margin/Rejected
# 2015-12-04, Order Canceled/Margin/Rejected
# 2015-12-07, Order Canceled/Margin/Rejected
# 2015-12-07, Order Canceled/Margin/Rejected
# 2015-12-07, Order Canceled/Margin/Rejected
# ...
# 2016-08-16, Order Canceled/Margin/Rejected
# 2016-08-16, Order Canceled/Margin/Rejected
# 2016-08-17, Order Canceled/Margin/Rejected
# 2016-08-17, Order Canceled/Margin/Rejected
# 2016-08-18, Order Canceled/Margin/Rejected
# 2016-08-18, Order Canceled/Margin/Rejected
# 2016-08-19, Order Canceled/Margin/Rejected
# 2016-08-19, Order Canceled/Margin/Rejected
# 2016-08-22, Order Canceled/Margin/Rejected
# 2016-08-22, Order Canceled/Margin/Rejected
# 2016-08-23, Order Canceled/Margin/Rejected
# 2016-08-23, Order Canceled/Margin/Rejected
# 2016-08-24, Order Canceled/Margin/Rejected
# 2016-08-24, Order Canceled/Margin/Rejected
# 2016-08-25, Order Canceled/Margin/Rejected
# 2016-08-25, Order Canceled/Margin/Rejected
# 2016-08-26, Order Canceled/Margin/Rejected
# 2016-08-26, Order Canceled/Margin/Rejected
# 2016-08-29, Order Canceled/Margin/Rejected
# 2016-08-29, Order Canceled/Margin/Rejected
# 2016-08-30, Order Canceled/Margin/Rejected
# 2016-08-30, Order Canceled/Margin/Rejected
# 2016-08-31, Order Canceled/Margin/Rejected
# 2016-08-31, Order Canceled/Margin/Rejected
# 2016-09-01, Order Canceled/Margin/Rejected
# 2016-09-01, Order Canceled/Margin/Rejected
# 2016-09-02, Order Canceled/Margin/Rejected
# 2016-09-02, Order Canceled/Margin/Rejected
# 2016-09-06, Order Canceled/Margin/Rejected
# 2016-09-06, Order Canceled/Margin/Rejected
# 2016-09-07, Order Canceled/Margin/Rejected
# 2016-09-07, Order Canceled/Margin/Rejected
# 2016-09-08, Order Canceled/Margin/Rejected
# 2016-09-08, Order Canceled/Margin/Rejected
# 2016-09-09, Order Canceled/Margin/Rejected
# 2016-09-09, Order Canceled/Margin/Rejected
# 2016-09-12, Order Canceled/Margin/Rejected
# 2016-09-12, Order Canceled/Margin/Rejected
# 2016-09-13, Order Canceled/Margin/Rejected
# 2016-09-13, Order Canceled/Margin/Rejected
# 2016-09-14, Order Canceled/Margin/Rejected
# 2016-09-14, Order Canceled/Margin/Rejected
# 2016-09-15, Order Canceled/Margin/Rejected
# 2016-09-15, Order Canceled/Margin/Rejected
# 2016-09-16, Order Canceled/Margin/Rejected
# 2016-09-16, Order Canceled/Margin/Rejected
# 2016-09-19, Order Canceled/Margin/Rejected
# 2016-09-19, Order Canceled/Margin/Rejected
# 2016-09-20, Order Canceled/Margin/Rejected
# 2016-09-20, Order Canceled/Margin/Rejected
# 2016-09-21, Order Canceled/Margin/Rejected
# 2016-09-21, Order Canceled/Margin/Rejected
# 2016-09-22, Order Canceled/Margin/Rejected
# 2016-09-22, Order Canceled/Margin/Rejected
# 2016-09-23, Order Canceled/Margin/Rejected
# 2016-09-23, Order Canceled/Margin/Rejected
# 2016-09-26, Order Canceled/Margin/Rejected
# 2016-09-26, Order Canceled/Margin/Rejected
# 2016-09-27, Order Canceled/Margin/Rejected
# 2016-09-27, Order Canceled/Margin/Rejected
# 2016-09-28, Order Canceled/Margin/Rejected
# 2016-09-28, Order Canceled/Margin/Rejected
# 2016-09-29, Order Canceled/Margin/Rejected
# 2016-09-29, Order Canceled/Margin/Rejected
# 2016-09-30, Order Canceled/Margin/Rejected
# 2016-09-30, Order Canceled/Margin/Rejected
# 2016-10-03, Order Canceled/Margin/Rejected
# 2016-10-03, Order Canceled/Margin/Rejected
# 2016-10-04, Order Canceled/Margin/Rejected
# 2016-10-04, Order Canceled/Margin/Rejected
# 2016-10-05, Order Canceled/Margin/Rejected
# 2016-10-05, Order Canceled/Margin/Rejected
# 2016-10-06, Order Canceled/Margin/Rejected
# 2016-10-06, Order Canceled/Margin/Rejected
# 2016-10-07, Order Canceled/Margin/Rejected
# 2016-10-07, Order Canceled/Margin/Rejected
# 2016-10-10, Order Canceled/Margin/Rejected
# 2016-10-10, Order Canceled/Margin/Rejected
# 2016-10-11, Order Canceled/Margin/Rejected
# 2016-10-11, Order Canceled/Margin/Rejected
# 2016-10-12, Order Canceled/Margin/Rejected
# 2016-10-12, Order Canceled/Margin/Rejected
# 2016-10-13, Order Canceled/Margin/Rejected
# 2016-10-13, Order Canceled/Margin/Rejected
# 2016-10-14, Order Canceled/Margin/Rejected
# 2016-10-14, Order Canceled/Margin/Rejected
# 2016-10-17, Order Canceled/Margin/Rejected
# 2016-10-17, Order Canceled/Margin/Rejected
# 2016-10-18, Order Canceled/Margin/Rejected
# 2016-10-18, Order Canceled/Margin/Rejected
# 2016-10-19, Order Canceled/Margin/Rejected
# 2016-10-19, Order Canceled/Margin/Rejected
# 2016-10-20, Order Canceled/Margin/Rejected
# 2016-10-20, Order Canceled/Margin/Rejected
# 2016-10-21, Order Canceled/Margin/Rejected
# 2016-10-21, Order Canceled/Margin/Rejected
# 2016-10-24, Order Canceled/Margin/Rejected
# 2016-10-24, Order Canceled/Margin/Rejected
# 2016-10-25, Order Canceled/Margin/Rejected
# 2016-10-25, Order Canceled/Margin/Rejected
# 2016-10-26, Order Canceled/Margin/Rejected
# 2016-10-26, Order Canceled/Margin/Rejected
# 2016-10-27, Order Canceled/Margin/Rejected
# 2016-10-27, Order Canceled/Margin/Rejected
# 2016-10-28, Order Canceled/Margin/Rejected
# 2016-10-28, Order Canceled/Margin/Rejected
# 2016-10-31, Order Canceled/Margin/Rejected
# 2016-10-31, Order Canceled/Margin/Rejected
# 2016-11-01, Order Canceled/Margin/Rejected
# 2016-11-01, Order Canceled/Margin/Rejected
# 2016-11-02, Order Canceled/Margin/Rejected
# 2016-11-02, Order Canceled/Margin/Rejected
# 2016-11-03, Order Canceled/Margin/Rejected
# 2016-11-03, Order Canceled/Margin/Rejected
# 2016-11-04, Order Canceled/Margin/Rejected
# 2016-11-04, Order Canceled/Margin/Rejected
# 2016-11-07, Order Canceled/Margin/Rejected
# 2016-11-07, Order Canceled/Margin/Rejected
# 2016-11-08, Order Canceled/Margin/Rejected
# 2016-11-08, Order Canceled/Margin/Rejected
# 2016-11-09, Order Canceled/Margin/Rejected
# 2016-11-09, Order Canceled/Margin/Rejected
# 2016-11-10, Order Canceled/Margin/Rejected
# 2016-11-10, Order Canceled/Margin/Rejected
# 2016-11-11, Order Canceled/Margin/Rejected
# 2016-11-11, Order Canceled/Margin/Rejected
# 2016-11-14, Order Canceled/Margin/Rejected
# 2016-11-14, Order Canceled/Margin/Rejected
# 2016-11-15, Order Canceled/Margin/Rejected
# 2016-11-15, Order Canceled/Margin/Rejected
# 2016-11-16, Order Canceled/Margin/Rejected
# 2016-11-16, Order Canceled/Margin/Rejected
# 2016-11-17, Order Canceled/Margin/Rejected
# 2016-11-17, Order Canceled/Margin/Rejected
# 2016-11-18, Order Canceled/Margin/Rejected
# 2016-11-18, Order Canceled/Margin/Rejected
# 2016-11-21, Order Canceled/Margin/Rejected
# 2016-11-21, Order Canceled/Margin/Rejected
# 2016-11-22, Order Canceled/Margin/Rejected
# 2016-11-22, Order Canceled/Margin/Rejected
# 2016-11-23, Order Canceled/Margin/Rejected
# 2016-11-23, Order Canceled/Margin/Rejected
# 2016-11-25, Order Canceled/Margin/Rejected
# 2016-11-25, Order Canceled/Margin/Rejected
# 2016-11-28, Order Canceled/Margin/Rejected
# 2016-11-28, Order Canceled/Margin/Rejected
# 2016-11-29, Order Canceled/Margin/Rejected
# 2016-11-29, Order Canceled/Margin/Rejected
# 2016-11-30, Order Canceled/Margin/Rejected
# 2016-11-30, Order Canceled/Margin/Rejected
# 2016-12-01, Order Canceled/Margin/Rejected
# 2016-12-01, Order Canceled/Margin/Rejected
# 2016-12-02, Order Canceled/Margin/Rejected
# 2016-12-02, Order Canceled/Margin/Rejected
# 2016-12-05, Order Canceled/Margin/Rejected
# 2016-12-05, Order Canceled/Margin/Rejected
# 2016-12-06, Order Canceled/Margin/Rejected
# 2016-12-06, Order Canceled/Margin/Rejected
# 2016-12-07, Order Canceled/Margin/Rejected
# 2016-12-07, Order Canceled/Margin/Rejected
# 2016-12-08, Order Canceled/Margin/Rejected
# 2016-12-08, Order Canceled/Margin/Rejected
# 2016-12-09, Order Canceled/Margin/Rejected
# 2016-12-09, Order Canceled/Margin/Rejected
# 2016-12-12, Order Canceled/Margin/Rejected
# 2016-12-12, Order Canceled/Margin/Rejected
# 2016-12-13, Order Canceled/Margin/Rejected
# 2016-12-13, Order Canceled/Margin/Rejected
# 2016-12-14, Order Canceled/Margin/Rejected
# 2016-12-14, Order Canceled/Margin/Rejected
# 2016-12-15, Order Canceled/Margin/Rejected
# 2016-12-15, Order Canceled/Margin/Rejected
# 2016-12-16, Order Canceled/Margin/Rejected
# 2016-12-16, Order Canceled/Margin/Rejected
# 2016-12-19, Order Canceled/Margin/Rejected
# 2016-12-19, Order Canceled/Margin/Rejected
# 2016-12-20, Order Canceled/Margin/Rejected
# 2016-12-20, Order Canceled/Margin/Rejected
# 2016-12-21, Order Canceled/Margin/Rejected
# 2016-12-21, Order Canceled/Margin/Rejected
# 2016-12-22, Order Canceled/Margin/Rejected
# 2016-12-22, Order Canceled/Margin/Rejected
# 2016-12-23, Order Canceled/Margin/Rejected
# 2016-12-23, Order Canceled/Margin/Rejected
# 2016-12-27, Order Canceled/Margin/Rejected
# 2016-12-27, Order Canceled/Margin/Rejected
# 2016-12-28, Order Canceled/Margin/Rejected
# 2016-12-28, Order Canceled/Margin/Rejected
# 2016-12-29, Order Canceled/Margin/Rejected
# 2016-12-29, Order Canceled/Margin/Rejected
# 2016-12-30, Order Canceled/Margin/Rejected
# 2016-12-30, Order Canceled/Margin/Rejected
# 2017-01-03, Order Canceled/Margin/Rejected
# 2017-01-03, Order Canceled/Margin/Rejected
# 2017-01-04, Order Canceled/Margin/Rejected
# 2017-01-04, Order Canceled/Margin/Rejected
# 2017-01-05, Order Canceled/Margin/Rejected
# 2017-01-05, Order Canceled/Margin/Rejected
# 2017-01-06, Order Canceled/Margin/Rejected
# 2017-01-06, Order Canceled/Margin/Rejected
# 2017-01-09, Order Canceled/Margin/Rejected
# 2017-01-09, Order Canceled/Margin/Rejected
# 2017-01-10, Order Canceled/Margin/Rejected
# 2017-01-10, Order Canceled/Margin/Rejected
# 2017-01-11, Order Canceled/Margin/Rejected
# 2017-01-11, Order Canceled/Margin/Rejected
# 2017-01-12, Order Canceled/Margin/Rejected
# 2017-01-12, Order Canceled/Margin/Rejected
# 2017-01-13, Order Canceled/Margin/Rejected
# 2017-01-13, Order Canceled/Margin/Rejected
# 2017-01-17, Order Canceled/Margin/Rejected
# 2017-01-17, Order Canceled/Margin/Rejected
# 2017-01-18, Order Canceled/Margin/Rejected
# 2017-01-18, Order Canceled/Margin/Rejected
# 2017-01-19, Order Canceled/Margin/Rejected
# 2017-01-19, Order Canceled/Margin/Rejected
# 2017-01-20, Order Canceled/Margin/Rejected
# 2017-01-20, Order Canceled/Margin/Rejected
# 2017-01-23, Order Canceled/Margin/Rejected
# 2017-01-23, Order Canceled/Margin/Rejected
# 2017-01-24, Order Canceled/Margin/Rejected
# 2017-01-24, Order Canceled/Margin/Rejected
# 2017-01-25, Order Canceled/Margin/Rejected
# 2017-01-25, Order Canceled/Margin/Rejected
# 2017-01-26, Order Canceled/Margin/Rejected
# 2017-01-26, Order Canceled/Margin/Rejected
# 2017-01-27, Order Canceled/Margin/Rejected
# 2017-01-27, Order Canceled/Margin/Rejected
# 2017-01-30, Order Canceled/Margin/Rejected
# 2017-01-30, Order Canceled/Margin/Rejected
# 2017-01-31, Order Canceled/Margin/Rejected
# 2017-01-31, Order Canceled/Margin/Rejected
# 2017-02-01, Order Canceled/Margin/Rejected
# 2017-02-01, Order Canceled/Margin/Rejected
# 2017-02-02, Order Canceled/Margin/Rejected
# 2017-02-02, Order Canceled/Margin/Rejected
# 2017-02-03, Order Canceled/Margin/Rejected
# 2017-02-03, Order Canceled/Margin/Rejected
# 2017-02-06, Order Canceled/Margin/Rejected
# 2017-02-06, Order Canceled/Margin/Rejected
# 2017-02-07, Order Canceled/Margin/Rejected
# 2017-02-07, Order Canceled/Margin/Rejected
# 2017-02-08, Order Canceled/Margin/Rejected
# 2017-02-08, Order Canceled/Margin/Rejected
# 2017-02-09, Order Canceled/Margin/Rejected
# 2017-02-09, Order Canceled/Margin/Rejected
# 2017-02-10, Order Canceled/Margin/Rejected
# 2017-02-13, Order Canceled/Margin/Rejected
# 2017-02-14, Order Canceled/Margin/Rejected
# 2017-02-15, Order Canceled/Margin/Rejected
# 2017-02-16, Order Canceled/Margin/Rejected
# 2017-02-17, Order Canceled/Margin/Rejected
# 2017-02-21, Order Canceled/Margin/Rejected
# 2017-02-22, Order Canceled/Margin/Rejected
# 2017-02-23, Order Canceled/Margin/Rejected
# 2017-02-24, Order Canceled/Margin/Rejected
# 2017-02-27, Order Canceled/Margin/Rejected
# 2017-02-28, Order Canceled/Margin/Rejected
# 2017-03-01, Order Canceled/Margin/Rejected
# 2017-03-02, Order Canceled/Margin/Rejected
# 2017-03-03, Order Canceled/Margin/Rejected
# 2017-03-06, Order Canceled/Margin/Rejected
# 2017-03-07, Order Canceled/Margin/Rejected
# 2017-03-08, Order Canceled/Margin/Rejected
# 2017-03-09, Order Canceled/Margin/Rejected
# 2017-03-10, Order Canceled/Margin/Rejected
# 2017-03-13, Order Canceled/Margin/Rejected
# 2017-03-14, Order Canceled/Margin/Rejected
# 2017-03-15, Order Canceled/Margin/Rejected
# 2017-03-16, Order Canceled/Margin/Rejected
# 2017-03-17, Order Canceled/Margin/Rejected
# 2017-03-20, Order Canceled/Margin/Rejected
# 2017-03-21, Order Canceled/Margin/Rejected
# 2017-03-22, Order Canceled/Margin/Rejected
# 2017-03-23, Order Canceled/Margin/Rejected
# 2017-03-24, Order Canceled/Margin/Rejected
# 2017-03-27, Order Canceled/Margin/Rejected
# 2017-03-28, Order Canceled/Margin/Rejected
# 2017-03-29, Order Canceled/Margin/Rejected
# 2017-03-30, Order Canceled/Margin/Rejected
# 2017-03-31, Order Canceled/Margin/Rejected
# 2017-04-03, Order Canceled/Margin/Rejected
# 2017-04-04, Order Canceled/Margin/Rejected
# 2017-04-05, Order Canceled/Margin/Rejected
# 2017-04-06, Order Canceled/Margin/Rejected
# 2017-04-07, Order Canceled/Margin/Rejected
# 2017-04-10, Order Canceled/Margin/Rejected
# 2017-04-11, Order Canceled/Margin/Rejected
# 2017-04-12, Order Canceled/Margin/Rejected
# 2017-04-13, Order Canceled/Margin/Rejected
# 2017-04-17, Order Canceled/Margin/Rejected
# 2017-04-18, Order Canceled/Margin/Rejected
# 2017-04-19, Order Canceled/Margin/Rejected
# 2017-04-20, Order Canceled/Margin/Rejected
# 2017-04-21, Order Canceled/Margin/Rejected
# 2017-04-24, Order Canceled/Margin/Rejected
# 2017-04-25, Order Canceled/Margin/Rejected
# 2017-04-26, Order Canceled/Margin/Rejected
# 2017-04-27, Order Canceled/Margin/Rejected
# 2017-04-28, Order Canceled/Margin/Rejected
# 2017-05-01, Order Canceled/Margin/Rejected
# 2017-05-02, Order Canceled/Margin/Rejected
# 2017-05-03, Order Canceled/Margin/Rejected
# 2017-05-04, Order Canceled/Margin/Rejected
# 2018-09-06, Order Canceled/Margin/Rejected
# 2018-09-07, Order Canceled/Margin/Rejected
# 2018-09-10, Order Canceled/Margin/Rejected
# 2018-09-11, Order Canceled/Margin/Rejected
# 2018-09-12, Order Canceled/Margin/Rejected
# 2018-09-13, Order Canceled/Margin/Rejected
# 2018-09-14, Order Canceled/Margin/Rejected
# 2018-09-17, Order Canceled/Margin/Rejected
# 2018-09-18, Order Canceled/Margin/Rejected
# 2018-09-19, Order Canceled/Margin/Rejected
# 2018-09-20, Order Canceled/Margin/Rejected
# 2018-09-21, Order Canceled/Margin/Rejected
# 2018-09-24, Order Canceled/Margin/Rejected
# 2018-09-25, Order Canceled/Margin/Rejected
# 2018-09-26, Order Canceled/Margin/Rejected
# 2018-09-27, Order Canceled/Margin/Rejected
# 2018-10-01, Order Canceled/Margin/Rejected
# 2018-10-02, Order Canceled/Margin/Rejected
# 2018-10-22, Order Canceled/Margin/Rejected
# 2018-10-23, Order Canceled/Margin/Rejected
# 2018-10-24, Order Canceled/Margin/Rejected
# 2018-10-25, Order Canceled/Margin/Rejected
# 2018-10-26, Order Canceled/Margin/Rejected
# 2018-10-29, Order Canceled/Margin/Rejected
# 2018-10-30, Order Canceled/Margin/Rejected
# 2018-10-31, Order Canceled/Margin/Rejected
# 2018-11-01, Order Canceled/Margin/Rejected
# 2018-11-02, Order Canceled/Margin/Rejected
# 2018-11-05, Order Canceled/Margin/Rejected
# 2018-11-06, Order Canceled/Margin/Rejected
# 2018-11-07, Order Canceled/Margin/Rejected
# 2018-11-08, Order Canceled/Margin/Rejected
# 2018-11-09, Order Canceled/Margin/Rejected
# 2018-11-12, Order Canceled/Margin/Rejected
# 2018-11-13, Order Canceled/Margin/Rejected
# 2018-11-14, Order Canceled/Margin/Rejected
# 2018-11-15, Order Canceled/Margin/Rejected
# 2018-11-16, Order Canceled/Margin/Rejected
# 2018-11-19, Order Canceled/Margin/Rejected
# 2018-11-20, Order Canceled/Margin/Rejected
# 2018-11-21, Order Canceled/Margin/Rejected
# 2018-11-23, Order Canceled/Margin/Rejected
# 2018-11-26, Order Canceled/Margin/Rejected
# 2018-11-27, Order Canceled/Margin/Rejected
# 2018-11-28, Order Canceled/Margin/Rejected
# 2018-11-29, Order Canceled/Margin/Rejected
# 2018-11-30, Order Canceled/Margin/Rejected
# 2018-12-03, Order Canceled/Margin/Rejected
# 2018-12-04, Order Canceled/Margin/Rejected
# 2018-12-06, Order Canceled/Margin/Rejected
# 2018-12-07, Order Canceled/Margin/Rejected
# 2018-12-10, Order Canceled/Margin/Rejected
# 2018-12-11, Order Canceled/Margin/Rejected
# 2018-12-12, Order Canceled/Margin/Rejected
# 2018-12-13, Order Canceled/Margin/Rejected
# 2018-12-14, Order Canceled/Margin/Rejected
# 2018-12-17, Order Canceled/Margin/Rejected
# 2018-12-18, Order Canceled/Margin/Rejected
# 2018-12-19, Order Canceled/Margin/Rejected
# 2018-12-20, Order Canceled/Margin/Rejected
# 2018-12-21, Order Canceled/Margin/Rejected
# 2018-12-24, Order Canceled/Margin/Rejected
# 2018-12-26, Order Canceled/Margin/Rejected
# 2018-12-27, Order Canceled/Margin/Rejected
# 2018-12-28, Order Canceled/Margin/Rejected
# 2018-12-31, Order Canceled/Margin/Rejected
# Final Portfolio Value: 590,820.3399999996
#
# Time to execute: 0:00:37.064787

# %% [markdown]
# ## Step 4: Evaluate the results

# %%
od = thestrat.analyzers.ar.get_analysis()
df = pd.DataFrame.from_dict(od, orient='index', columns=['Annual Return'])
df
# Out:
#       Annual Return
# 2008       0.000000
# 2009       0.494554
# 2010       0.188499
# 2011       0.002460
# 2012       0.177876
# 2013       0.293102
# 2014       0.062001
# 2015      -0.059436
# 2016       0.165201
# 2017       0.168064
# 2018      -0.198813

# %%
avg_annual_return = (final_value / initial_value) ** (1 / (df.iloc[-1].name - df.iloc[0].name)) - 1
print(f'Average annual return: {avg_annual_return:.1%}')
# Out:
# Average annual return: 11.4%

# %% [markdown]
# Get benchmark to compare:

# %%
spy = pdr.get_data_yahoo(symbols='SPY', start=get_trading_data('NKE').index[0], end=get_trading_data('NKE').index[-1])
spy = spy[['Adj Close']]
spy.columns = ['S&P 500']

# %%
portfolio_value = thestrat.observers[0].value.plot()
df_comp = pd.DataFrame(portfolio_value, columns=['Portfolio Value'], index=get_trading_data('NKE').index)
df_comp = pd.concat([df_comp, spy], axis=1)
df_comp = df_comp / df_comp.ix[0, :]
df_comp.plot(figsize=(16, 9))

# %%
cash = thestrat.observers[0].cash.plot()
df_cash = pd.DataFrame(cash, index=get_trading_data('NKE').index, columns=['Cash'])
df_cash.plot(figsize=(16, 9))

# %% [markdown]
# ## Next steps

# %% [markdown]
# The current implementation performs significantly worse than S&P 500. The following next steps are needed to improve the results:
# - **Selling strategy**. We are not selling, just buying and holding. We should implement a selling strategy once a company hits a certain criteria.
# - **Portfolio allocation**. We are simply purchasing the same amount in USD for every company that passes the criteria. We should implement a way to rank the opportunities and allocate the cash accordingly to the size of the opportunity.
# - **Cash**. The cash is sitting in the bank while time passes, not yielding anything. We should simulate purchasing SPY index or something else.
# - **Survivor bias**. We are excluding companies which ceased to trade before the end of the simulation. We should include them back, treating the dataframe with trading data (i.e. filling close prices with zero).
#
# We should also investigate why PB ratio criteria actually pull the results down. Finally, when implementing **Enterprise Investor** (next project), we will do it in the cloud ([Paperspace](https://www.paperspace.com) or [Floydhub](https://www.floydhub.com)).

# %% [markdown]
# # Download Daily Prices, PE & PB data from all companies passing Defensive Investor Criteria

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
import numpy as np
import quandl
import os
import warnings
from datetime import datetime
from tqdm import tqdm_notebook as tqdm
import pandas_datareader as pdr
import matplotlib.pyplot as plt
from collections import defaultdict
from graham import *

warnings.filterwarnings('ignore')
quandl.ApiConfig.api_key = os.getenv('QUANDL_APY_KEY')

# %% [markdown]
# ## List of ALL companies passing criteria
# This just loads companies passing the criteria, saved in a pickle file by the end of [Evolution of companies meeting Defensive Investor criteria notebook](http://localhost:8888/notebooks/Evolution%20of%20companies%20meeting%20Defensive%20Investor%20criteria.ipynb).
#
# This is a very time consuming process:
# - It takes aprox. **1'45"/date** to test the whole Sharadar common stocks' database of 14,000 companies
# - This means, for past 10 years, to test all 14,000 companies on a monthly basis (12 x 120) **takes aprox 3h30min**

# %%
import pickle

def load_obj(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)
    
fname = os.path.join(os.getcwd(), 'data_defensive', 'defensive2_companies_20081231_20181231.pkl')
dic = load_obj(fname)

# %%
all_companies_passing_in_period = set()
for key, value in dic.items():
    print(f'{key:%Y-%m-%d}: {len(value)} companies pass criteria')
    for el in value:
        all_companies_passing_in_period.add(el)
        
all_companies_passing_in_period = list(all_companies_passing_in_period)
print(f'All period: {len(all_companies_passing_in_period)} companies pass criteria')
# Out:
# 2008-12-31: 30 companies pass criteria
# 2009-01-31: 30 companies pass criteria
# 2009-02-28: 38 companies pass criteria
# 2009-03-31: 37 companies pass criteria
# 2009-04-30: 37 companies pass criteria
# 2009-05-31: 37 companies pass criteria
# 2009-06-30: 37 companies pass criteria
# 2009-07-31: 38 companies pass criteria
# 2009-08-31: 36 companies pass criteria
# 2009-09-30: 35 companies pass criteria
# 2009-10-31: 35 companies pass criteria
# 2009-11-30: 34 companies pass criteria
# 2009-12-31: 35 companies pass criteria
# 2010-01-31: 35 companies pass criteria
# 2010-02-28: 33 companies pass criteria
# 2010-03-31: 34 companies pass criteria
# 2010-04-30: 34 companies pass criteria
# 2010-05-31: 34 companies pass criteria
# 2010-06-30: 34 companies pass criteria
# 2010-07-31: 33 companies pass criteria
# 2010-08-31: 33 companies pass criteria
# 2010-09-30: 34 companies pass criteria
# 2010-10-31: 33 companies pass criteria
# 2010-11-30: 33 companies pass criteria
# 2010-12-31: 32 companies pass criteria
# 2011-01-31: 32 companies pass criteria
# 2011-02-28: 35 companies pass criteria
# 2011-03-31: 36 companies pass criteria
# 2011-04-30: 36 companies pass criteria
# 2011-05-31: 37 companies pass criteria
# 2011-06-30: 37 companies pass criteria
# 2011-07-31: 37 companies pass criteria
# 2011-08-31: 39 companies pass criteria
# 2011-09-30: 40 companies pass criteria
# 2011-10-31: 40 companies pass criteria
# 2011-11-30: 40 companies pass criteria
# 2011-12-31: 41 companies pass criteria
# 2012-01-31: 41 companies pass criteria
# 2012-02-29: 44 companies pass criteria
# 2012-03-31: 47 companies pass criteria
# 2012-04-30: 47 companies pass criteria
# 2012-05-31: 46 companies pass criteria
# 2012-06-30: 46 companies pass criteria
# 2012-07-31: 46 companies pass criteria
# 2012-08-31: 45 companies pass criteria
# 2012-09-30: 45 companies pass criteria
# 2012-10-31: 45 companies pass criteria
# 2012-11-30: 45 companies pass criteria
# 2012-12-31: 45 companies pass criteria
# 2013-01-31: 45 companies pass criteria
# 2013-02-28: 50 companies pass criteria
# 2013-03-31: 50 companies pass criteria
# 2013-04-30: 50 companies pass criteria
# 2013-05-31: 50 companies pass criteria
# 2013-06-30: 51 companies pass criteria
# 2013-07-31: 51 companies pass criteria
# 2013-08-31: 52 companies pass criteria
# 2013-09-30: 52 companies pass criteria
# 2013-10-31: 52 companies pass criteria
# 2013-11-30: 52 companies pass criteria
# 2013-12-31: 52 companies pass criteria
# 2014-01-31: 53 companies pass criteria
# 2014-02-28: 64 companies pass criteria
# 2014-03-31: 63 companies pass criteria
# 2014-04-30: 63 companies pass criteria
# 2014-05-31: 63 companies pass criteria
# 2014-06-30: 65 companies pass criteria
# 2014-07-31: 65 companies pass criteria
# 2014-08-31: 65 companies pass criteria
# 2014-09-30: 64 companies pass criteria
# 2014-10-31: 64 companies pass criteria
# 2014-11-30: 66 companies pass criteria
# 2014-12-31: 67 companies pass criteria
# 2015-01-31: 67 companies pass criteria
# 2015-02-28: 64 companies pass criteria
# 2015-03-31: 62 companies pass criteria
# 2015-04-30: 63 companies pass criteria
# 2015-05-31: 64 companies pass criteria
# 2015-06-30: 64 companies pass criteria
# 2015-07-31: 64 companies pass criteria
# 2015-08-31: 66 companies pass criteria
# 2015-09-30: 66 companies pass criteria
# 2015-10-31: 67 companies pass criteria
# 2015-11-30: 64 companies pass criteria
# 2015-12-31: 62 companies pass criteria
# 2016-01-31: 62 companies pass criteria
# 2016-02-29: 58 companies pass criteria
# 2016-03-31: 55 companies pass criteria
# 2016-04-30: 56 companies pass criteria
# 2016-05-31: 57 companies pass criteria
# 2016-06-30: 55 companies pass criteria
# 2016-07-31: 55 companies pass criteria
# 2016-08-31: 53 companies pass criteria
# 2016-09-30: 52 companies pass criteria
# 2016-10-31: 51 companies pass criteria
# 2016-11-30: 49 companies pass criteria
# 2016-12-31: 49 companies pass criteria
# 2017-01-31: 48 companies pass criteria
# 2017-02-28: 43 companies pass criteria
# 2017-03-31: 39 companies pass criteria
# 2017-04-30: 39 companies pass criteria
# 2017-05-31: 39 companies pass criteria
# 2017-06-30: 38 companies pass criteria
# 2017-07-31: 37 companies pass criteria
# 2017-08-31: 36 companies pass criteria
# 2017-09-30: 37 companies pass criteria
# 2017-10-31: 37 companies pass criteria
# 2017-11-30: 39 companies pass criteria
# 2017-12-31: 39 companies pass criteria
# 2018-01-31: 39 companies pass criteria
# 2018-02-28: 39 companies pass criteria
# 2018-03-31: 39 companies pass criteria
# 2018-04-30: 39 companies pass criteria
# 2018-05-31: 39 companies pass criteria
# 2018-06-30: 39 companies pass criteria
# 2018-07-31: 41 companies pass criteria
# 2018-08-31: 41 companies pass criteria
# 2018-09-30: 41 companies pass criteria
# 2018-10-31: 41 companies pass criteria
# 2018-11-30: 39 companies pass criteria
# 2018-12-31: 40 companies pass criteria
# All period: 114 companies pass criteria

# %% [markdown]
# ## Retrieve the data from web and save it on disc

# %%
def batch_download_price_pepb(list_companies, filename, start_date, end_date, batch_size=20):
    def batch(iterable, n=1):
        l = len(iterable)
        for ndx in range(0, l, n):
            yield iterable[ndx:min(ndx + n, l)]

    list_dfs = []
    i = 1
    for b in batch(list_companies, batch_size):
        print(f'Batch {i}: from {b[0]} to {b[-1]}')
        df1 = quandl.get_table('SHARADAR/SEP', ticker=b, date={'gte': start_date, 'lte': end_date}, paginate=True,
                            qopts={"columns":['ticker', 'date', 'open', 'high', 'low', 'close', 'volume']})

        df2 = quandl.get_table('SHARADAR/DAILY', ticker=b, date={'gte': start_date, 'lte': end_date}, paginate=True,
                                qopts={"columns":['ticker', 'date', 'pe', 'pb']})
        result = pd.merge(df1, df2, on=['ticker', 'date'])
        result.sort_values(['ticker', 'date'], inplace=True)

        list_dfs.append(result)
        i += 1

    final_df = pd.concat(list_dfs, axis=0)
    final_df.to_csv(filename)
    return final_df

# %%
dr = pd.date_range('2008-12-31', '2018-12-31', freq='M')
fname = os.path.join(os.getcwd(), 'data_defensive', 'defensive2_pricedata_20081231_20181231.csv')
df = batch_download_price_pepb(all_companies_passing_in_period, fname, start_date=dr[0], end_date=dr[-1])
df
# Out:
# Batch 1: from SEB to HRS
# Batch 2: from FAST to UVV
# Batch 3: from CW to HFC
# Batch 4: from MCO to HRL
# Batch 5: from LB to JWN
# Batch 6: from EXPD to VZ
#       ticker       date   open    high    low  close      volume   pe   pb
# 48463    ADM 2008-12-31  28.77  29.010  28.60  28.83   4250200.0  7.7  1.4
# 48462    ADM 2009-01-02  28.93  29.230  28.52  29.19   5808500.0  7.8  1.4
# 48461    ADM 2009-01-05  28.92  29.500  28.61  29.08   6677000.0  7.7  1.4
# 48460    ADM 2009-01-06  29.26  29.260  28.20  28.29  13002500.0  7.5  1.3
# 48459    ADM 2009-01-07  28.05  28.710  27.87  28.34  13265500.0  7.5  1.3
# 48458    ADM 2009-01-08  28.13  28.310  27.57  27.76   7361200.0  7.4  1.3
# 48457    ADM 2009-01-09  27.77  28.170  27.67  27.96   7054900.0  7.4  1.3
# 48456    ADM 2009-01-12  27.50  28.000  26.74  26.90   7366300.0  7.2  1.3
# 48455    ADM 2009-01-13  26.84  28.080  26.53  27.88   8891600.0  7.4  1.3
# 48454    ADM 2009-01-14  26.27  26.390  24.08  24.25  14894100.0  6.5  1.1
# 48453    ADM 2009-01-15  24.59  25.660  24.35  25.30  11663800.0  6.7  1.2
# 48452    ADM 2009-01-16  25.79  25.880  24.88  25.62   8184100.0  6.8  1.2
# 48451    ADM 2009-01-20  25.38  26.100  25.04  25.12   9942900.0  6.7  1.2
# 48450    ADM 2009-01-21  25.62  27.180  25.51  27.12   9023300.0  7.2  1.3
# 48449    ADM 2009-01-22  26.65  27.640  26.39  26.86   9289000.0  7.1  1.3
# 48448    ADM 2009-01-23  26.31  27.240  25.68  26.93   7875200.0  7.2  1.3
# 48447    ADM 2009-01-26  27.05  27.845  26.94  27.50   6879800.0  7.3  1.3
# 48446    ADM 2009-01-27  27.65  27.930  27.26  27.79  10391400.0  7.4  1.3
# 48445    ADM 2009-01-28  28.01  28.230  27.73  28.09   8872200.0  7.5  1.3
# 48444    ADM 2009-01-29  27.19  27.620  26.87  27.43  10723600.0  7.3  1.3
# 48443    ADM 2009-01-30  27.31  27.970  26.89  27.38  10496500.0  7.3  1.3
# 48442    ADM 2009-02-02  26.70  27.810  26.51  27.50  11728400.0  7.3  1.3
# 48441    ADM 2009-02-03  28.35  28.750  26.16  27.65  12461600.0  7.4  1.3
# 48440    ADM 2009-02-04  27.01  27.100  24.99  25.54  15783600.0  6.8  1.2
# 48439    ADM 2009-02-05  25.50  26.920  25.43  26.66  10090500.0  7.1  1.3
# 48438    ADM 2009-02-06  26.63  27.770  26.58  27.61   7194700.0  7.3  1.3
# 48437    ADM 2009-02-09  27.43  29.260  27.35  29.03  12518900.0  7.4  1.4
# 48436    ADM 2009-02-10  28.35  29.030  28.10  28.52  13438500.0  7.3  1.3
# 48435    ADM 2009-02-11  28.65  28.770  27.48  27.99   7815400.0  7.1  1.3
# 48434    ADM 2009-02-12  27.41  28.570  27.13  28.54   7182700.0  7.3  1.3
# ...      ...        ...    ...     ...    ...    ...         ...  ...  ...
# 29      XRAY 2018-11-15  35.83  37.000  35.58  36.98   3061471.0 -5.7  1.8
# 28      XRAY 2018-11-16  36.76  37.400  36.31  37.20   7847531.0 -5.7  1.8
# 27      XRAY 2018-11-19  37.24  37.590  36.76  36.92   1876037.0 -5.7  1.8
# 26      XRAY 2018-11-20  36.71  37.260  36.27  36.92   2833080.0 -5.7  1.8
# 25      XRAY 2018-11-21  36.99  37.200  36.79  36.89   2150701.0 -5.7  1.8
# 24      XRAY 2018-11-23  36.77  37.700  36.45  36.51    697147.0 -5.6  1.8
# 23      XRAY 2018-11-26  36.86  37.150  36.62  37.00   2117494.0 -5.7  1.8
# 22      XRAY 2018-11-27  36.86  37.380  36.57  37.18   3067956.0 -5.7  1.8
# 21      XRAY 2018-11-28  37.33  37.550  36.67  37.54   2887267.0 -5.8  1.9
# 20      XRAY 2018-11-29  37.54  37.700  36.98  36.99   1979574.0 -5.7  1.8
# 19      XRAY 2018-11-30  37.04  37.910  36.71  37.78   2642006.0 -5.8  1.9
# 18      XRAY 2018-12-03  37.95  38.580  37.65  37.83   1515308.0 -5.8  1.9
# 17      XRAY 2018-12-04  37.76  37.910  36.72  36.81   3148503.0 -5.6  1.8
# 16      XRAY 2018-12-06  36.36  36.510  35.60  36.47   3367268.0 -5.6  1.8
# 15      XRAY 2018-12-07  36.33  36.990  35.97  36.31   1926456.0 -5.6  1.8
# 14      XRAY 2018-12-10  36.33  36.570  35.73  36.46   1957657.0 -5.6  1.8
# 13      XRAY 2018-12-11  36.81  37.630  36.64  37.00   3426573.0 -5.7  1.8
# 12      XRAY 2018-12-12  37.42  38.900  37.42  38.12   5112352.0 -5.9  1.9
# 11      XRAY 2018-12-13  38.13  38.500  37.24  37.72   2556595.0 -5.8  1.9
# 10      XRAY 2018-12-14  37.57  37.570  36.30  36.97   2853708.0 -5.7  1.8
# 9       XRAY 2018-12-17  36.81  37.830  36.59  37.17   2621860.0 -5.7  1.8
# 8       XRAY 2018-12-18  37.36  37.460  35.92  36.51   3490385.0 -5.6  1.8
# 7       XRAY 2018-12-19  36.50  36.840  35.63  35.96   3184975.0 -5.5  1.8
# 6       XRAY 2018-12-20  35.95  36.155  34.94  35.48   2874073.0 -5.4  1.8
# 5       XRAY 2018-12-21  35.68  36.300  35.37  35.65   3942363.0 -5.5  1.8
# 4       XRAY 2018-12-24  35.53  35.870  34.93  35.46   1204217.0 -5.4  1.8
# 3       XRAY 2018-12-26  35.58  37.240  35.24  37.19   2304429.0 -5.7  1.8
# 2       XRAY 2018-12-27  36.66  37.130  36.12  37.12   1993861.0 -5.7  1.8
# 1       XRAY 2018-12-28  37.33  37.670  36.90  37.10   1742966.0 -5.7  1.8
# 0       XRAY 2018-12-31  37.28  37.545  36.76  37.21   1640178.0 -5.7  1.8
#
# [274931 rows x 9 columns]

# %%
df['ticker'].nunique()
# Out:
# 113
